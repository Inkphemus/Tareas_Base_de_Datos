# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo 14

# %% [markdown]
# ## Integrantes:
# * Fabián Clavijo Fernández - 201921039-4
# * Sebastián Cornejo Soto - 201921055-6
# * Tomás Ramdohr Arellano - 201921022-k

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\fabia\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (2.0.25)
# Requirement already satisfied: sqlparse in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\fabia\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\fabia\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\fabia\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in c:\users\fabia\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\fabia\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\fabia\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\fabia\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\fabia\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\fabia\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\fabia\anaconda3\lib\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:Basedegallos@localhost:5432/my_BD
# Out:
# env: DATABASE_URL=postgresql://postgres:Basedegallos@localhost:5432/my_BD

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='my_BD',
   password="Basedegallos"
)

print(conn)
# Out:
# <connection object at 0x000002564A5449D0; dsn: 'user=postgres password=xxx dbname=my_BD host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (id_director INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_director))
# Out:
# (psycopg2.errors.DuplicateTable) la relación «director» ya existe
#
# [SQL: CREATE TABLE director (id_director INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (id_actor INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_actor))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «actor» ya existe
#
# [SQL: CREATE TABLE actor (id_actor INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_actor))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (id_pelicula INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# nombre VARCHAR(45),
# genero VARCHAR(45),
# duracion INT,
# fecha_publicacion DATE,
# PRIMARY KEY (id_pelicula),
# FOREIGN KEY (id_director) REFERENCES director(id_director))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «pelicula» ya existe
#
# [SQL: CREATE TABLE pelicula (id_pelicula INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# nombre VARCHAR(45),
# genero VARCHAR(45),
# duracion INT,
# fecha_publicacion DATE,
# PRIMARY KEY (id_pelicula),
# FOREIGN KEY (id_director) REFERENCES director(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (id_actor INT,
#                                           id_pelicula INT,
#                                           PRIMARY KEY (id_actor, id_pelicula),
#                                           FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#                                           FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «actor_participa_en_pelicula» ya existe
#
# [SQL: CREATE TABLE actor_participa_en_pelicula (id_actor INT,
#                                           id_pelicula INT,
#                                           PRIMARY KEY (id_actor, id_pelicula),
#                                           FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#                                           FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_director) REFERENCES director(id_director))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_director» ya existe
#
# [SQL: CREATE TABLE premio_mejor_director (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_director) REFERENCES director(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_actor INT,
# anio INT,
# PRIMARY KEY (id_premio),
# FOREIGN KEY(id_actor) REFERENCES actor(id_actor))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_actor» ya existe
#
# [SQL: CREATE TABLE premio_mejor_actor (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_actor INT,
# anio INT,
# PRIMARY KEY (id_premio),
# FOREIGN KEY(id_actor) REFERENCES actor(id_actor))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_pelicula INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_pelicula) REFERENCES pelicula(id_pelicula))
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_pelicula» ya existe
#
# [SQL: CREATE TABLE premio_mejor_pelicula (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_pelicula INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_pelicula) REFERENCES pelicula(id_pelicula))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date

#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()
premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 2006, 'director': 71, 'genero': 'Animación', 'cast': [], 'mejor pelicula': 'no'}, 2: {'año': 2010, 'director': 176, 'genero': 'Western', 'cast': [68], 'mejor pelicula': 'no'}, 3: {'año': 2010, 'director': 140, 'genero': 'Acción', 'cast': [77], 'mejor pelicula': 'no'}, 4: {'año': 2010, 'director': 55, 'genero': 'Terror', 'cast': [37], 'mejor pelicula': 'no'}, 5: {'año': 2011, 'director': 128, 'genero': 'Misterio', 'cast': [170], 'mejor pelicula': 'no'}, 6: {'año': 2006, 'director': 22, 'genero': 'Western', 'cast': [16, 187, 173], 'mejor pelicula': 'no'}, 7: {'año': 1965, 'director': 181, 'genero': 'Suspense', 'cast': [176], 'mejor pelicula': 'no'}, 8: {'año': 2015, 'director': 31, 'genero': 'Acción', 'cast': [155, 130], 'mejor pelicula': 'no'}, 9: {'año': 2010, 'director': 139, 'genero': 'Drama', 'cast': [87, 7], 'mejor pelicula': 'no'}, 10: {'año': 1970, 'director': 186, 'genero': 'Aventura', 'cast': [10], 'mejor pelicula': 'no'}, 11: {'año': 1967, 'director': 72, 'genero': 'Romance', 'cast': [185], 'mejor pelicula': 'no'}, 12: {'año': 1980, 'director': 24, 'genero': 'Aventura', 'cast': [193, 162], 'mejor pelicula': 'no'}, 13: {'año': 1984, 'director': 143, 'genero': 'Romance', 'cast': [46], 'mejor pelicula': 'no'}, 14: {'año': 1985, 'director': 152, 'genero': 'Western', 'cast': [77], 'mejor pelicula': 'no'}, 15: {'año': 1974, 'director': 76, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 16: {'año': 1974, 'director': 105, 'genero': 'Fantasía', 'cast': [103], 'mejor pelicula': 'no'}, 17: {'año': 1992, 'director': 61, 'genero': 'Comedia', 'cast': [192, 200], 'mejor pelicula': 'no'}, 18: {'año': 2021, 'director': 96, 'genero': 'Romance', 'cast': [47, 174, 102], 'mejor pelicula': 'no'}, 19: {'año': 2015, 'director': 68, 'genero': 'Western', 'cast': [62, 67, 155], 'mejor pelicula': 'no'}, 20: {'año': 1981, 'director': 75, 'genero': 'Suspense', 'cast': [166, 153, 132], 'mejor pelicula': 'no'}, 21: {'año': 1990, 'director': 46, 'genero': 'Suspense', 'cast': [185, 48], 'mejor pelicula': 'no'}, 22: {'año': 2016, 'director': 34, 'genero': 'Acción', 'cast': [97], 'mejor pelicula': 'no'}, 23: {'año': 1977, 'director': 35, 'genero': 'Musical', 'cast': [7], 'mejor pelicula': 'no'}, 24: {'año': 1972, 'director': 160, 'genero': 'Documental', 'cast': [176, 19], 'mejor pelicula': 'no'}, 25: {'año': 1986, 'director': 143, 'genero': 'Documental', 'cast': [177], 'mejor pelicula': 'no'}, 26: {'año': 1989, 'director': 197, 'genero': 'Romance', 'cast': [113], 'mejor pelicula': 'no'}, 27: {'año': 2012, 'director': 162, 'genero': 'Suspense', 'cast': [115, 137, 35], 'mejor pelicula': 'no'}, 28: {'año': 1973, 'director': 26, 'genero': 'Animación', 'cast': [169], 'mejor pelicula': 'no'}, 29: {'año': 1992, 'director': 77, 'genero': 'Fantasía', 'cast': [128, 121, 109], 'mejor pelicula': 'no'}, 30: {'año': 2019, 'director': 34, 'genero': 'Documental', 'cast': [108], 'mejor pelicula': 'no'}, 31: {'año': 1989, 'director': 192, 'genero': 'Suspense', 'cast': [73, 113, 182, 118], 'mejor pelicula': 'no'}, 32: {'año': 1995, 'director': 93, 'genero': 'Ciencia ficción', 'cast': [98], 'mejor pelicula': 'no'}, 33: {'año': 1984, 'director': 12, 'genero': 'Ciencia ficción', 'cast': [142, 27, 41], 'mejor pelicula': 'no'}, 34: {'año': 1962, 'director': 101, 'genero': 'Drama', 'cast': [50, 81, 45], 'mejor pelicula': 'no'}, 35: {'año': 2002, 'director': 157, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 36: {'año': 1974, 'director': 106, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 37: {'año': 2002, 'director': 113, 'genero': 'Western', 'cast': [95, 8], 'mejor pelicula': 'no'}, 38: {'año': 2016, 'director': 85, 'genero': 'Terror', 'cast': [196, 92, 78], 'mejor pelicula': 'no'}, 39: {'año': 1960, 'director': 146, 'genero': 'Aventura', 'cast': [133], 'mejor pelicula': 'no'}, 40: {'año': 1960, 'director': 60, 'genero': 'Musical', 'cast': [76], 'mejor pelicula': 'no'}, 41: {'año': 1977, 'director': 51, 'genero': 'Western', 'ca ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre
# FROM pelicula
# WHERE fecha_publicacion > '2023-04-12'
# --En la tabla películas se muestran solo aquellas donde el campo fecha_publicacion sean mayor que 12 de abril de 2023
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 2 rows affected.
# [('El prisionero de el grito',), ('La invasión de el mago',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre, fecha_publicacion
# FROM pelicula
# WHERE genero = 'Drama' AND
# EXTRACT(YEAR FROM fecha_publicacion) = 2023
# --Se selecciona el nombre y la fecha de la tabla película
# --Cuando el género es drama y el año 2023
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 1 rows affected.
# [('El prisionero de el grito', datetime.date(2023, 8, 8))]

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre
# FROM actor
# WHERE id_actor IN(
#     SELECT id_actor
#     FROM actor_participa_en_pelicula
#     WHERE id_pelicula IN(
#         SELECT id_pelicula
#         FROM pelicula
#         WHERE genero = 'Comedia'
#     )
# )
# --Se seleccionan los nombres de los actores que estén en la combinación de: actor-película con género comedia
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 34 rows affected.
# [('Leonardo Etxebarria',),
#  ('Genghis Urbina',),
#  ('Nadia Wu',),
#  ('Fadhila Xavier',),
#  ('Orhan Sousa',),
#  ('Elif Diniz',),
#  ('Tatiana Qian',),
#  ('Rashid Xavier',),
#  ('Fabiana Henriquez',),
#  ('Elena Pacheco',),
#  ('Valeria Teixeira',),
#  ('Zoya Ramos',),
#  ('Valeria Inácio',),
#  ('Pilar Queiroz',),
#  ('Wilhelmina Nguyen',),
#  ('Mikhail Montenegro',),
#  ('Orhan Olivares',),
#  ('Nadia Pacheco',),
#  ('Umberto Almeida',),
#  ('Vivek Jimenez',),
#  ('Aarav Carvalho',),
#  ('Rosa Joaquim',),
#  ('Pilar Gao',),
#  ('Giovanni Queiroz',),
#  ('Alessandro Lima',),
#  ('Patricia Fernandes',),
#  ('Wilhelmina Inácio',),
#  ('Gustavo Abadi',),
#  ('Alessandro Nunes',),
#  ('Hiroko Tan',),
#  ('Rania Cruz',),
#  ('Dmitri Uchoa',),
#  ('Beatriz Queiroz',),
#  ('Orhan Santana',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# WITH
# tabla1 AS(
#     SELECT pelicula.id_pelicula AS id_pel, pelicula.genero AS gen_pel
#     FROM pelicula
#     ORDER BY pelicula.genero
# ),
# --Corresponde a los Id de las películas y su género
# tabla2 AS(
#     SELECT premio_mejor_pelicula.id_pelicula AS id_pel, COUNT(premio_mejor_pelicula.id_premio) AS pre_pel
#     FROM pelicula
#     INNER JOIN premio_mejor_pelicula ON pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
#     GROUP BY premio_mejor_pelicula.id_pelicula
# ),
# --Corresponde al id de la película y el número de su o sus premios
# tabla3 AS(
#     SELECT tabla1.gen_pel, tabla2.pre_pel
#     FROM tabla1
#     INNER JOIN tabla2 ON tabla1.id_pel = tabla2.id_pel
# ),
# --Corresponde la combinación de la tabla1 y de la tabla2
# tabla4 AS(
#     SELECT tabla3.gen_pel AS genero, SUM(tabla3.pre_pel) AS total_premios
#     FROM tabla3
#     GROUP BY tabla3.gen_pel
# ),
# --Realiza la suma de premios por cada género de la tabla3
# tabla5 AS(
#     SELECT tabla4.genero ,  tabla4.total_premios
#     FROM tabla4
#     ORDER BY tabla4.total_premios DESC
# )
# --Ordena la tabla4 por el número de premios
# SELECT * FROM tabla5
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 12 rows affected.
# [('Western', Decimal('5')),
#  ('Documental', Decimal('4')),
#  ('Ciencia ficción', Decimal('3')),
#  ('Animación', Decimal('3')),
#  ('Misterio', Decimal('3')),
#  ('Aventura', Decimal('3')),
#  ('Fantasía', Decimal('2')),
#  ('Comedia', Decimal('2')),
#  ('Drama', Decimal('2')),
#  ('Suspense', Decimal('2')),
#  ('Terror', Decimal('1')),
#  ('Romance', Decimal('1'))]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT * FROM(
#     SELECT pelicula.nombre, COUNT(actor.nombre) AS cuenta
#     FROM pelicula, actor_participa_en_pelicula, actor
#     WHERE pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
#         AND actor.id_actor = actor_participa_en_pelicula.id_actor
#     GROUP BY pelicula.nombre
#     ORDER BY COUNT(actor.nombre) DESC)
# WHERE cuenta > 1
# --Se seleccionan todos los campos nombre y cantidad de actores cuando el id_pelicula y el id_actor relaciónan respectivamente: película y actor
# --La agrupación se hacer por el nombre de pelocula y la cantidad de actores se realiza en el campo nombre de el actor
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT t_p.nombre AS nombre_pelicula,
#            MAX(t_a.edad) AS edad_actor_mayor,
#            MIN(t_a.edad) AS edad_actor_menor
#
#   FROM pelicula t_p
#
#   INNER JOIN actor_participa_en_pelicula t_ap ON
#              t_p.id_pelicula = t_ap.id_pelicula
#   INNER JOIN actor t_a ON
#              t_ap.id_actor = t_a.id_actor
#
#     GROUP BY t_p.nombre
#     ORDER BY ABS(MAX(t_a.edad) - MIN(t_a.edad))
#     DESC
#     LIMIT 1
#
# --Se combinan las tablas actor y participa_en_pelicula con película
# -- a partir de ahí se agrupan por nombre de película y se ordena por
# --una función compuesta de el Valord Absoluto de la diferencia
# --de los máximos y mínimos sobre el campo de edad de la tabla
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 1 rows affected.
# [('La llegada de la luz', 69, 15)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT anio
# FROM premio_mejor_pelicula
# WHERE id_pelicula =
# (SELECT id_pelicula
#  FROM pelicula
#  ORDER BY duracion
#  LIMIT 1)
#  --Se selecciona el año de la tabla: premio al mejor actor cuando su ID es una de las películas de mayor duración
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH
# tabla1 AS(
#     SELECT t_a.nombre, t_a.id_actor, COUNT(DISTINCT t_p.id_director) AS dir_num
#     FROM director t_d
#     INNER JOIN pelicula t_p ON
#         t_d.id_director = t_p.id_director
#     INNER JOIN actor_participa_en_pelicula t_ap ON
#         t_p.id_pelicula = t_ap.id_pelicula
#     INNER JOIN actor t_a ON
#         t_ap.id_actor = t_a.id_actor
#     GROUP BY t_a.id_actor
#     HAVING COUNT(DISTINCT t_p.id_director) > 1
# ),
# --La tabla corresponde a el número de directores por cada actor identificado por su id y nombre
#
# tabla2 AS(
#     SELECT pp.nombre AS nombre_de_una_pelicula, tabla1.id_actor
#     FROM tabla1
#     INNER JOIN actor_participa_en_pelicula app ON
#         tabla1.id_actor = app.id_actor
#     INNER JOIN pelicula pp ON
#         app.id_pelicula = pp.id_pelicula
# ),
# --Asigna para cada director una de sus películas
#
# tabla3 AS(
#     SELECT tabla1.nombre, tabla1.dir_num, tabla2.nombre_de_una_pelicula
#     FROM tabla1
#     INNER JOIN tabla2 ON
#         tabla1.id_actor = tabla2.id_actor
# )
# SELECT * FROM tabla3
#
#
# --Se debvuelve la tabla combinación de el actor de interés, es decir, tabla uno, con la relación entre un director y una de ssus película,es decir tabla 2
# --Adicionalmente por parte de el actor solo se selecciona el nombre y no el id
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 465 rows affected.
# [('Mikhail Montenegro', 3, 'El amanecer de la caverna'),
#  ('Giovanni Velez', 3, 'La resurrección de el ángel'),
#  ('Pilar Yilmaz', 2, 'La senda de la princesa'),
#  ('Wan Esteves', 6, 'La búsqueda del tesoro de el hechicero'),
#  ('Rashid Xavier', 6, 'El lamento de la bruja'),
#  ('Jasmin Janssen', 2, 'La profecía de el destino'),
#  ('Qiu Almeida', 3, 'El grito de el dragón'),
#  ('Pilar Sousa', 3, 'La cripta de la paz'),
#  ('Darya Urbina', 2, 'El caballero de la caverna'),
#  ('Lakshmi Yan', 2, 'El lamento de la flor'),
#  ('Quintus Wu', 4, 'El ritual de el valle'),
#  ('Dmitri Ortega', 3, 'La tormenta de la heroína'),
#  ('Lakshmi Montenegro', 3, 'El tesoro escondido de la aventura'),
#  ('Patricia Fernandes', 5, 'La estirpe de el descubrimiento'),
#  ('Genghis Urbina', 4, 'La batalla de el puente'),
#  ('Tatjana Oliveira', 3, 'El descubrimiento de el perdón'),
#  ('Rashid Xavier', 6, 'El último viaje de el abismo'),
#  ('Han Teles', 4, 'La fortuna de la noche'),
#  ('Quintus Wu', 4, 'La leyenda perdida de el rincón'),
#  ('Nina Ivanov', 4, 'El enigma de la despedida'),
#  ('Ximena Uchoa', 4, 'La profecía de el misterio'),
#  ('Mehmet Olivares', 3, 'El misterio de el secreto'),
#  ('Orhan Santana', 2, 'El lamento de el enigma'),
#  ('Mehmet Olivares', 3, 'El arco iris de la magia'),
#  ('Hiroko Nguyen', 5, 'El canto de sirena de la oscuridad'),
#  ('Nadia Wu', 3, 'La leyenda de el sueño'),
#  ('Vivek Figueiredo', 2, 'El caballero de la heroína'),
#  ('Valeria Ueno', 4, 'El canto de sirena de la oscuridad'),
#  ('Mehmet Queiroz', 4, 'El secreto oscuro de el tesoro'),
#  ('Pilar Yilmaz', 2, 'La rebelión de la espada'),
#  ('Pilar Pereira', 6, 'La rebelión de la sonrisa'),
#  ('Darya Fernandes', 2, 'La profecía de la huida'),
#  ('Rashid Xavier', 6, 'El secreto oscuro de el tesoro'),
#  ('Mehmet Etxebarria', 5, 'La resurrección de la aventura'),
#  ('Leonardo Lima', 3, 'El misterio de el secreto'),
#  ('Pilar Gao', 4, 'El canto de sirena de la espada mágica'),
#  ('Fabiana Henriquez', 2, 'La cripta de la nube'),
#  ('Kamala Diniz', 3, 'La doncella de la redención'),
#  ('Aarav Velez', 2, 'La llegada de el renacer'),
#  ('Lakshmi Ferreira', 2, 'La venganza de el enigma'),
#  ('Dmitri Ortega', 3, 'El laberinto de el castillo'),
#  ('Qiu Goncalves', 2, 'El espejismo de el bosque'),
#  ('Ximena Zhang', 3, 'La venganza de la sombra'),
#  ('Nina Nguyen', 2, 'La batalla de la venganza'),
#  ('Mehmet Janssen', 5, 'La maldición de la alianza'),
#  ('Yusef Yan', 2, 'La historia de la clave'),
#  ('Wan Esteves', 6, 'La travesía de el explorador'),
#  ('Ilya Rocha', 4, 'El arco iris de la verdad'),
#  ('Xavier Estevez', 3, 'El arco iris de la montaña'),
#  ('Katarina Janssen', 2, 'La batalla de el puente'),
#  ('Fadhila Ortega', 4, 'La fortuna de la pasión'),
#  ('Rania Cruz', 2, 'El laberinto de el susurro'),
#  ('Giovanni Estevez', 3, 'La profecía de la aventura'),
#  ('Hiroko Nguyen', 5, 'El bosque encantado de el amor'),
#  ('Chiyoko Santana', 6, 'El caballero de la guerra'),
#  ('Katarina Janssen', 2, 'El viaje de el camino'),
#  ('Katarina Ivanov', 2, 'El enigma de la estrella'),
#  ('Pilar Sousa', 3, 'La leyenda de la pesadilla'),
#  ('Ximena Uchoa', 4, 'El viaje de el camino'),
#  ('Wan Borges', 6, 'La leyenda perdida de el puente'),
#  ('Vivek Jimenez', 6, 'El castillo de el hechizo'),
#  ('Giovanni Velez', 3, 'El ritual de el valle'),
#  ('Wilhelmina Nguyen', 3, 'La llave de la cárcel'),
#  ('Mina Zhang', 3, 'El cuento de hadas de el tesoro'),
#  ('Orhan Olivares', 4, 'La doncella de la ola'),
#  ('Theresa Rodriguez', 4, 'La profecía de la verdad'),
#  ('Elena Petrov', 4, 'El destino de la magia'),
#  ('Isa Hernandez', 6, 'La estirpe de el descubrimiento'),
#  ('Emiko Joaquim', 3, 'La rebelión de el fuego'),
#  ('Wang Nunes', 5, 'La venganza de la luz'),
#  ('Dmitri Uchoa', 3, 'El destino de el amor'),
#  ('Omar Mendes', 5, 'La estrella fugaz de la esperanza'),
#  ('Orhan Olivares', 4, 'El ritual de la guerra'),
#  ('Leonardo Gao', 3, 'La misión de el laberinto'),
#  ('Wilhelmina Abadi', 2, 'La senda de el hechicero'),
#  ('Lakshmi Montenegro', 3, 'La leyenda perdida de el sacrificio'),
#  ('Yuri Yamamoto', 4, 'La maldición del vampiro de la estrella fugaz'),
#  ('Leonardo Lima', 3, 'La rebelión de la sonrisa'),
#  ('Bianca Nogueira', 3, 'El arco iris de la montaña'),
#  ('Hiroko Dutta', 4, 'El amanecer de la academia'),
#  ('Xavier Estevez', 3, 'La profecía de la huida'),
#  ('Aarav Velez', 2, 'Las aventuras de la tormenta'),
#  ('Theresa Olivares', 6, 'El lamento de el unicornio'),
#  ('Quintus Rocha', 4, 'La odisea de el mago'),
#  ('Omar Mendes', 5, 'El hechizo de el grito'),
#  ('Zoya Tan', 3, 'El laberinto de el muro'),
#  ('Zoya Tan', 3, 'El lamento de la flor'),
#  ('Javier Quintana', 2, 'La cripta de el jardín'),
#  ('Fadhila Ortega', 4, 'El amanecer de el castillo'),
#  ('Elif Vieira', 2, 'La profecía de la cripta'),
#  ('Quintus Wu', 4, 'El viajero de la criatura'),
#  ('Chidike Santana', 3, 'El lamento de la guerra'),
#  ('Bianca Nogueira', 3, 'El lamento de el enigma'),
#  ('Wang Nunes', 5, 'La cripta de la desgracia'),
#  ('Nadia Pacheco', 3, 'La travesía del océano de el río'),
#  ('Umar Oliveira', 2, 'El lamento de la traición'),
#  ('Darya Fernandes', 2, 'La doncella de la redención'),
#  ('Alessandro Nunes', 3, 'La historia de la clave'),
#  ('Genghis Urbina', 4, 'El ritual de la guerra'),
#  ('Orhan Velez', 4, 'El amanecer de la pesadilla'),
#  ('Quentin Jimenez', 2, 'La conquista de la luz'),
#  ('Ursula Pacheco', 2, 'La danza macabra de la soledad'),
#  ('Hanako Xu', 2, 'La cripta de el jardín'),
#  ('Hiroko Nguyen', 5, 'La leyenda de la pesadilla'),
#  ('Umberto Almeida', 3, 'La resurrección de la aventura'),
#  ('Bianca Nogueira', 3, 'El espejismo de la caída'),
#  ('Wilhelmina Inácio', 3, 'La búsqueda de el abismo'),
#  ('Xavier Dutta', 4, 'El caballero de la guerra'),
#  ('Ximena Uchoa', 4, 'El despertar de la aldea'),
#  ('Xin Ramos', 2, 'El lamento de la flor'),
#  ('Giovanni Queiroz', 3, 'La cripta de la desgracia'),
#  ('Nadia Rodriguez', 2, 'La senda de la sonrisa'),
#  ('Javier Jimenez', 3, 'La fortuna de la pasión'),
#  ('Tatjana Oliveira', 3, 'La maldición de el sol'),
#  ('Isa Hernandez', 6, 'El arco iris de la magia'),
#  ('Ximena Zhang', 3, 'El laberinto de la ley'),
#  ('Omar Mendes', 5, 'La travesía sin retorno de el jardín'),
#  ('Ilya Rocha', 4, 'La danza macabra de el tesoro'),
#  ('Isa Hernandez', 6, 'El misterio de el encuentro'),
#  ('Chiyoko Santana', 6, 'La invasión de el mago'),
#  ('Zoya Gomes', 4, 'El renacimiento de la neblina'),
#  ('Gustavo Pacheco', 3, 'El pacto de la expedición'),
#  ('Genghis Figueiredo', 2, 'La estirpe de la profecía'),
#  ('Zafar Olivares', 2, 'El resurgimiento de la leyenda'),
#  ('Tatiana Qian', 2, 'El espejismo de la fuga'),
#  ('Kamala Goncalves', 2, 'La leyenda de el sueño'),
#  ('Tatjana Oliveira', 3, 'El destino de la magia'),
#  ('Yusef Yan', 2, 'El refugio de la cueva'),
#  ('Xavier Estevez', 3, 'El laberinto de el laberinto'),
#  ('Qiu Goncalves', 2, 'El lamento de la traición'),
#  ('Javier Jimenez', 3, 'La leyenda perdida de el rincón'),
#  ('Natalia Velez', 4, 'El caballero de la heroína'),
#  ('Nadia Pacheco', 3, 'El refugio de la cueva'),
#  ('Sakura Carvalho', 3, 'La profecía de el misterio'),
#  ('Darya Abadi', 2, 'El pacto de la luna'),
#  ('Umberto Zambrano', 5, 'El bosque encantado de la traición'),
#  ('Yasmin Rodriguez', 5, 'La leyenda de la pesadilla'),
#  ('Valeria Inácio', 4, 'El laberinto de el susurro'),
#  ('Valeria Ueno', 4, 'El viajero de el destino'),
#  ('Leonardo Etxebarria', 6, 'La leyenda perdida de el sacrificio'),
#  ('Tatjana Pacheco', 2, 'El lamento de el enigma'),
#  ('Lakshmi Yan', 2, 'El lamento de el enigma'),
#  ('Umar Oliveira', 2, 'El vuelo de el amor'),
#  ('Valeria Inácio', 4, 'El espejismo de la caída'),
#  ('Zoya Sousa', 3, 'La conquista de la luz'),
#  ('Beatriz Zhang', 4, 'El misterio de la huida'),
#  ('Chidike Santana', 3, 'El vuelo mágico de el amor'),
#  ('Nina Ivanov', 4, 'El viaje de la luna'),
#  ('Lakshmi Diniz', 2, 'El tesoro escondido de el hechicero'),
#  ('Xin Ramos', 2, 'El caballero de la heroína'),
#  ('Isa Hernandez', 6, 'El lamento de el enigma'),
#  ('Nina Ivanov', 4, 'El bosque encantado de la fortuna'),
#  ('Leticia Velez', 3, 'El refugio de la cascada'),
#  ('Wang Kumar', 2, 'La senda de el hechicero'),
#  ('Chiyoko Santana', 6, 'El arco iris de la oscuridad'),
#  ('Nina Olivares', 2, 'El eclipse de el jardín'),
#  ('Ximena Uchoa', 4, 'El regreso de la noche'),
#  ('Elif Diniz', 4, 'La resurrección de la aventura'),
#  ('Zoya Sousa', 3, 'La estirpe de la maraña'),
#  ('Elif Hidalgo', 3, 'El príncipe de la caverna'),
#  ('Orhan Olivares', 4, 'El refugio de la cueva'),
#  ('Wan Borges', 6, 'La venganza de la sombra'),
#  ('Mina Zhang', 3, 'La resurrección de la reina'),
#  ('Natalia Velez', 4, 'La batalla de el héroe'),
#  ('Beatriz Zhang', 4, 'El lamento de la guerra'),
#  ('Javier Yan', 2, 'La historia de la clave'),
#  ('Zoya Sousa', 3, 'La trampa de la bienvenida'),
#  ('Javier Jimenez', 3, 'El amanecer de la bestia'),
#  ('Nina Olivares', 2, 'La danza macabra de el tesoro'),
#  ('Orhan Velez', 4, 'El caballero de la caverna'),
#  ('Theresa Rodriguez', 4, 'El regreso de el vuelo'),
#  ('Darya Abadi', 2, 'El refugio de la cascada'),
#  ('Rosa Ortega', 2, 'El prisionero de el sacrificio'),
#  ('Elena Pacheco', 4, 'El caballero de el sol'),
#  ('Elena Ortega', 2, 'La conquista de la esperanza'),
#  ('Zoya Yilmaz', 3, 'El laberinto de la ley'),
#  ('Kamala Diniz', 3, 'El renacimiento de la neblina'),
#  ('Yuri Yamamoto', 4, 'El amanecer de la academia'),
#  ('Giovanni Lopes', 3, 'El vuelo de la ciudad'),
#  ('Beatriz Queiroz', 3, 'La búsqueda de el viajero'),
#  ('Theresa Olivares', 6, 'La maldición de el sol'),
#  ('Mikhail Zhang', 2, 'La misión de la leyenda'),
#  ('Rashid Xavier', 6, 'La travesía del océano de el adiós'),
#  ('Rosa Joaquim', 2, 'El último viaje de el abismo'),
#  ('Beatriz Zhang', 4, 'El cuento de hadas de el peligro'),
#  ('Pilar Pereira', 6, 'La travesura de el ángel'),
#  ('Pilar Pereira', 6, 'La venganza de el enigma'),
#  ('Ursula Pacheco', 2, 'El resurgimiento de el laberinto'),
#  ('Alessandro Joaquim', 2, 'El caballero de el león'),
#  ('Isa Hernandez', 6, 'El eclipse de la ciudad'),
#  ('Beatriz Queiroz', 3, 'El laberinto de el susurro'),
#  ('Wan Esteves', 6, 'La trampa de el cielo'),
#  ('Hiroko Nguyen', 5, 'La profecía de la huida'),
#  ('Lakshmi Ferreira', 2, 'El refugio de la cascada'),
#  ('Mehmet Queiroz', 4, 'La fuente de la profecía'),
#  ('Tatiana Qian', 2, 'El destino de la magia'),
#  ('Vivek Jimenez', 6, 'El grito de el castillo'),
#  ('Darya Figueiredo', 4, 'La danza macabra de la flor'),
#  ('Leonardo Etxebarria', 6, 'El resurgimiento de la prisión'),
#  ('Quintus Rocha', 4, 'El regreso de la gruta'),
#  ('Alessandro Joaquim', 2, 'La misión de la leyenda'),
#  ('Katarina Lima', 2, 'La leyenda de el perdón'),
#  ('Quintus Inácio', 4, 'El lamento de el unicornio'),
#  ('Orhan Velez', 4, 'La batalla de el renacimiento'),
#  ('Pilar Queiroz', 6, 'La escalada de el laberinto'),
#  ('Pilar Gao', 4, 'El secreto de la perdición'),
#  ('Wang Kumar', 2, 'La metamorfosis de el abismo'),
#  ('Hiroko Nguyen', 5, 'La doncella de la corrupción'),
#  ('Quentin Jimenez', 2, 'La batalla de el puente'),
#  ('Yuri Yamamoto', 4, 'El lamento de la amistad'),
#  ('Quintus Inácio', 4, 'El laberinto de la ley'),
#  ('Nadia Wu', 3, 'La llegada de el laberinto'),
#  ('Orhan Sousa', 2, 'La fuga de la compañía'),
#  ('Mehmet Janssen', 5, 'El resurgimiento de la leyenda'),
#  ('Wang Nunes', 5, 'El prisionero de el valle'),
#  ('Rania Cruz', 2, 'El regreso de el jardín'),
#  ('Natalia Oliveira', 3, 'La estirpe de la leyenda'),
#  ('Giovanni Estevez', 3, 'El laberinto de el muro'),
#  ('Nadia Pacheco', 3, 'El tesoro de el horizonte'),
#  ('Jin Etxebarria', 3, 'El misterio de el legado'),
#  ('Leonardo Bianchi', 2, 'La cripta de la nube'),
#  ('Leonardo Lima', 3, 'El tesoro escondido de el hechicero'),
#  ('Pilar Queiroz', 6, 'El secreto de la perdición'),
#  ('Chiyoko Santana', 6, 'El lamento de el unicornio'),
#  ('Pilar Gao', 4, 'El último viaje de el abismo'),
#  ('Giovanni Lopes', 3, 'El misterio de el legado'),
#  ('Pilar Queiroz', 6, 'La cripta de la paz'),
#  ('Yasmin Rodriguez', 5, 'El renacimiento de la prisión'),
#  ('Nadia Wu', 3, 'El caballero de la espada'),
#  ('Wilhelmina Xia', 2, 'El arco iris de la montaña'),
#  ('Mehmet Queiroz', 4, 'La maldición de el sol'),
#  ('Javier Ueno', 2, 'El bosque encantado de la guerra'),
#  ('Nadia Rodriguez', 2, 'La fortuna de la esperanza'),
#  ('Fabiana Henriquez', 2, 'El regreso de el abismo'),
#  ('Genghis Figueiredo', 2, 'La batalla de el océano'),
#  ('Umberto Almeida', 3, 'La travesía del océano de el adiós'),
#  ('Orhan Olivares', 4, 'La estirpe de la leyenda'),
#  ('Theresa Olivares', 6, 'El eclipse de la redención'),
#  ('Fadhila Ortega', 4, 'La trampa de la bienvenida'),
#  ('Xavier Dutta', 4, 'El caballero de la maraña'),
#  ('Kamala Diniz', 3, 'El caballero de la guerra'),
#  ('Zoya Tan', 3, 'La invasión de el dragón'),
#  ('Giovanni Lopes', 3, 'La resurrección de la aventura'),
#  ('Rosa Ortega', 2, 'El cuento de hadas de el puente'),
#  ('Valeria Teixeira', 3, 'El laberinto de el susurro'),
#  ('Han Teles', 4, 'El caballero de el sol'),
#  ('Emiko Joaquim', 3, 'El descubrimiento de el perdón'),
#  ('Leonardo Etxebarria', 6, 'El espejismo de la profecía'),
#  ('Vivek Jimenez', 6, 'El lamento de la amistad'),
#  ('Qiu Almeida', 3, 'El castillo de el amor'),
#  ('Yuri Santana', 3, 'La rebelión de el fuego'),
#  ('Zoya Yilmaz', 3, 'La estirpe de el descubrimiento'),
#  ('Khaled Wu', 3, 'La danza macabra de la flor'),
#  ('Mehmet Etxebarria', 5, 'El lamento de la guerra'),
#  ('Bianca Ortega', 2, 'El vuelo mágico de la caída'),
#  ('Umberto Zambrano', 5, 'La profecía de la oscuridad'),
#  ('Pilar Pereira', 6, 'El pacto de la expedición'),
#  ('Hiroko Dutta', 4, 'La invasión de el lamento'),
#  ('Katarina Ivanov', 2, 'El lamento de la bruja'),
#  ('Xavier Dutta', 4, 'La conquista de la luz'),
#  ('Orhan Kumar', 2, 'La llegada de el renacer'),
#  ('Vivek Jimenez', 6, 'El viaje de la luna'),
#  ('Vivek Jimenez', 6, 'La llave de la cárcel'),
#  ('Genghis Urbina', 4, 'El bosque encantado de la guerra'),
#  ('Valeria Teixeira', 3, 'El grito de el dragón'),
#  ('Yuri Santana', 3, 'La conquista de la revelación'),
#  ('Yuri Yamamoto', 4, 'El destino de el amor'),
#  ('Mehmet Janssen', 5, 'La fuga de el ángel'),
#  ('Javier Jimenez', 3, 'El misterio de el encuentro'),
#  ('Elena Petrov', 4, 'El lamento de el cielo'),
#  ('Jin Etxebarria', 3, 'El resurgimiento de la leyenda'),
#  ('Yuri Iglesias', 2, 'La rebelión de el adiós'),
#  ('Patricia Fernandes', 5, 'La danza de el sueño'),
#  ('Fadhila Xavier', 2, 'El caballero de la espada'),
#  ('Theresa Olivares', 6, 'La leyenda de el sueño'),
#  ('Umberto Zambrano', 5, 'La rebelión de el adiós'),
#  ('Khaled Wu', 3, 'El vuelo mágico de la espada mágica'),
#  ('Wan Borges', 6, 'La redención de la caverna'),
#  ('Wilhelmina Nguyen', 3, 'El viajero de el destino'),
#  ('Yasmin Rodriguez', 5, 'La búsqueda de la nube'),
#  ('Wan Esteves', 6, 'La invasión de el renacimiento'),
#  ('Elif Diniz', 4, 'La misión de la leyenda'),
#  ('Natalia Vargas', 2, 'La doncella de el sueño'),
#  ('Leonardo Gao', 3, 'El regreso de la noche'),
#  ('Rashid Xavier', 6, 'La batalla de el puente'),
#  ('Patricia Fernandes', 5, 'El pacto de la expedición'),
#  ('Fadhila Xavier', 2, 'El secreto oscuro de el árbol'),
#  ('Tatjana Pacheco', 2, 'La estirpe de el vuelo'),
#  ('Dmitri Uchoa', 3, 'La venganza de el volcán'),
#  ('Zoya Gomes', 4, 'El eclipse de la redención'),
#  ('Mehmet Queiroz', 4, 'El misterio de el laberinto'),
#  ('Wan Borges', 6, 'El camino hacia la estrella fugaz'),
#  ('Yusef Kawaguchi', 3, 'El vuelo de la noche'),
#  ('Elena Ortega', 2, 'La maldición de el sol'),
#  ('Patricia Fernandes', 5, 'La llegada de la luz'),
#  ('Xavier Zambrano', 2, 'El resurgimiento de la leyenda'),
#  ('Beatriz Zhang', 4, 'El guardián de el sapo'),
#  ('Zafar Nogueira', 6, 'El vuelo mágico de la espada mágica'),
#  ('Rosa Joaquim', 2, 'El regreso de el vuelo'),
#  ('Wang Nunes', 5, 'La resurrección de la reina'),
#  ('Elif Hidalgo', 3, 'La batalla de el misterio'),
#  ('Isa Hernandez', 6, 'El secreto oscuro de la travesía'),
#  ('Qiu Almeida', 3, 'El hechizo de el pacto'),
#  ('Pilar Sousa', 3, 'El misterio de el legado'),
#  ('Chiyoko Santana', 6, 'El grito de el dragón'),
#  ('Elena Petrov', 4, 'La resurrección de la puerta'),
#  ('Gustavo Pacheco', 3, 'El regreso de la prisión'),
#  ('Hanako Xu', 2, 'El vuelo mágico de el amor'),
#  ('Yusef Kawaguchi', 3, 'El lamento de la flor'),
#  ('Chidike Santana', 3, 'La doncella de la corrupción'),
#  ('Theresa Olivares', 6, 'El eclipse de la guerra'),
#  ('Pilar Queiroz', 6, 'El vuelo de la resistencia'),
#  ('Vivek Jimenez', 6, 'El secreto oscuro de el tesoro'),
#  ('Quintus Inácio', 4, 'El misterio de la huida'),
#  ('Orhan Santana', 2, 'La venganza de el volcán'),
#  ('Rania Kumar', 3, 'El resurgimiento de el laberinto'),
#  ('Alessandro Nunes', 3, 'La búsqueda de el viajero'),
#  ('Lakshmi Diniz', 2, 'El regreso de el vuelo'),
#  ('Pilar Queiroz', 6, 'La doncella de la corrupción'),
#  ('Mina Zhang', 3, 'El tesoro escondido de el hechicero'),
#  ('Javier Quintana', 2, 'El lamento de la guerra'),
#  ('Wang Nunes', 5, 'El cuento de hadas de el peligro'),
#  ('Darya Pacheco', 2, 'El caballero de la caverna'),
#  ('Leticia Velez', 3, 'La tormenta de la heroína'),
#  ('Oscar Gomes', 2, 'El guardián de la bailarina'),
#  ('Aarav Carvalho', 2, 'La llegada de la luz'),
#  ('Mehmet Janssen', 5, 'El tesoro de el horizonte'),
#  ('Pilar Pereira', 6, 'El secreto oscuro de el árbol'),
#  ('Elena Pacheco', 4, 'El regreso de la noche'),
#  ('Elif Vieira', 2, 'El grito de la noche'),
#  ('Xavier Zambrano', 2, 'La venganza de la luz'),
#  ('Elif Diniz', 4, 'El caballero de la maraña'),
#  ('Theresa Rodriguez', 4, 'El lamento de el unicornio'),
#  ('Zafar Nogueira', 6, 'El destino de el amor'),
#  ('Khaled Wu', 3, 'El canto de sirena de la oscuridad'),
#  ('Darya Figueiredo', 4, 'La travesía de la desgracia'),
#  ('Quintus Rocha', 4, 'La escalada de el laberinto'),
#  ('Oscar Gomes', 2, 'El regreso de la fortuna'),
#  ('Giovanni Queiroz', 3, 'La metamorfosis de el abismo'),
#  ('Zoya Martinez', 2, 'La profecía de la cripta'),
#  ('Pilar Pereira', 6, 'El príncipe de la academia'),
#  ('Beatriz Queiroz', 3, 'El tesoro escondido de la aventura'),
#  ('Natalia Oliveira', 3, 'El pacto de la expedición'),
#  ('Fadhila Ortega', 4, 'El destino de el sol'),
#  ('Quintus Rocha', 4, 'La maldición del vampiro de la sirena'),
#  ('Kamala Goncalves', 2, 'El laberinto de el castillo'),
#  ('Leonardo Bianchi', 2, 'La profecía de el destino'),
#  ('Natalia Oliveira', 3, 'El tesoro de el pacto'),
#  ('Umberto Zambrano', 5, 'El lamento de el río'),
#  ('Darya Figueiredo', 4, 'El destino de el camino'),
#  ('Elena Pacheco', 4, 'El castillo de el unicornio'),
#  ('Valeria Inácio', 4, 'El cuento de hadas de el puente'),
#  ('Han Teles', 4, 'El laberinto de la trampa'),
#  ('Pilar Pereira', 6, 'El prisionero de la bestia'),
#  ('Orhan Sousa', 2, 'La llegada de la luz'),
#  ('Darya Figueiredo', 4, 'La senda de el hechicero'),
#  ('Pilar Queiroz', 6, 'La llegada de el laberinto'),
#  ('Darya Pacheco', 2, 'La cripta de la nube'),
#  ('Giovanni Estevez', 3, 'La invasión de el renacimiento'),
#  ('Gustavo Pacheco', 3, 'La rebelión de la espada'),
#  ('Yuri Iglesias', 2, 'La estirpe de la leyenda'),
#  ('Darya Urbina', 2, 'El pacto de la expedición'),
#  ('Nina Nguyen', 2, 'El destino de la caída'),
#  ('Emiko Joaquim', 3, 'La fuente de la profecía'),
#  ('Elif Hidalgo', 3, 'La fuga de la compañía'),
#  ('Sakura Nogueira', 2, 'La metamorfosis de el abismo'),
#  ('Katarina Lima', 2, 'El castillo de el hechizo'),
#  ('Giovanni Velez', 3, 'La danza macabra de el sueño'),
#  ('Hiroko Dutta', 4, 'La maldición del vampiro de la estrella fugaz'),
#  ('Mehmet Etxebarria', 5, 'La danza macabra de el tesoro'),
#  ('Dmitri Uchoa', 3, 'La búsqueda de la nube'),
#  ('Nina Ivanov', 4, 'El tesoro escondido de el misterio'),
#  ('Genghis Urbina', 4, 'El prisionero de el valle'),
#  ('Yusef Kawaguchi', 3, 'La metamorfosis de el abismo'),
#  ('Leonardo Etxebarria', 6, 'La leyenda de el perdón'),
#  ('Vivek Figueiredo', 2, 'La metamorfosis de el rincón'),
#  ('Rania Kumar', 3, 'El viaje de el peligro'),
#  ('Omar Mendes', 5, 'La batalla de el océano'),
#  ('Rashid Xavier', 6, 'El secreto de la perdición'),
#  ('Zafar Nogueira', 6, 'Las aventuras de la tormenta'),
#  ('Zafar Nogueira', 6, 'El viaje de el camino'),
#  ('Alessandro Nunes', 3, 'La invasión de el guardián'),
#  ('Javier Yan', 2, 'El camino hacia la estrella fugaz'),
#  ('Mehmet Etxebarria', 5, 'El castillo de el hechizo'),
#  ('Wilhelmina Inácio', 3, 'El secreto de la perdición'),
#  ('Mehmet Olivares', 3, 'El hechizo de el pacto'),
#  ('Xavier Zambrano', 2, 'Las aventuras de la tormenta'),
#  ('Wan Esteves', 6, 'La estrella fugaz de la esperanza'),
#  ('Jasmin Janssen', 2, 'La conquista de la luz'),
#  ('Rania Kumar', 3, 'El caballero de la espada'),
#  ('Theresa Rodriguez', 4, 'La travesura de el ángel'),
#  ('Elena Pacheco', 4, 'La llegada de la luz'),
#  ('Javier Jimenez', 3, 'La redención de la caverna'),
#  ('Oscar Correia', 2, 'La leyenda perdida de el rincón'),
#  ('Aarav Carvalho', 2, 'El renacimiento de la pesadilla'),
#  ('Yasmin Rodriguez', 5, 'El grito de el amor'),
#  ('Sakura Carvalho', 3, 'La travesía sin retorno de el jardín'),
#  ('Orhan Kumar', 2, 'El viajero de la ola'),
#  ('Natalia Vargas', 2, 'La resurrección de el ángel'),
#  ('Natalia Velez', 4, 'El vuelo de la resistencia'),
#  ('Han Teles', 4, 'La redención de el héroe'),
#  ('Zoya Yilmaz', 3, 'El misterio de el laberinto'),
#  ('Oscar Correia', 2, 'El enigma de la revelación'),
#  ('Valeria Ueno', 4, 'El destino de la puerta'),
#  ('Zoya Gomes', 4, 'El lamento de el unicornio'),
#  ('Zafar Olivares', 2, 'La cripta de el viajero'),
#  ('Mehmet Queiroz', 4, 'El prisionero de el sueño'),
#  ('Mikhail Zhang', 2, 'La profecía de el misterio'),
#  ('Zara Nogueira', 2, 'La redención de la caverna'),
#  ('Umberto Zambrano', 5, 'La doncella de la redención'),
#  ('Leticia Velez', 3, 'El bosque encantado de la cueva'),
#  ('Sakura Nogueira', 2, 'La danza macabra de la flor'),
#  ('Isa Kawaguchi', 2, 'El laberinto de la corrupción'),
#  ('Ximena Zhang', 3, 'El último viaje de el ángel'),
#  ('Javier Ueno', 2, 'La fuga de el ángel'),
#  ('Valeria Ueno', 4, 'El pacto de la expedición'),
#  ('Chiyoko Santana', 6, 'El prisionero de el sueño'),
#  ('Orhan Velez', 4, 'La profecía de el misterio'),
#  ('Wilhelmina Xia', 2, 'La rebelión de la espada'),
#  ('Wilhelmina Abadi', 2, 'El viajero de la corrupción'),
#  ('Rosa Ortega', 2, 'La batalla de el océano'),
#  ('Mehmet Janssen', 5, 'El cuento de hadas de el puente'),
#  ('Elif Diniz', 4, 'La travesía del océano de el río'),
#  ('Wan Borges', 6, 'La profecía de la oscuridad'),
#  ('Dmitri Ortega', 3, 'El príncipe de la caverna'),
#  ('Mikhail Montenegro', 3, 'La travesía del océano de el adiós'),
#  ('Sakura Carvalho', 3, 'La cripta de el viajero'),
#  ('Zafar Nogueira', 6, 'La fortuna de la noche'),
#  ('Leonardo Gao', 3, 'El regreso de el sol'),
#  ('Yuri Santana', 3, 'La senda de el hechicero'),
#  ('Quintus Inácio', 4, 'El camino hacia la huida'),
#  ('Natalia Velez', 4, 'La danza macabra de la flor'),
#  ('Natalia Velez', 4, 'La cripta de el jardín'),
#  ('Mikhail Montenegro', 3, 'La misión de el laberinto'),
#  ('Javier Jimenez', 3, 'La venganza de la sombra'),
#  ('Elena Petrov', 4, 'El vuelo de la resistencia'),
#  ('Wan Esteves', 6, 'El renacimiento de la neblina'),
#  ('Mehmet Etxebarria', 5, 'La profecía de la verdad'),
#  ('Isa Kawaguchi', 2, 'El regreso de el vuelo'),
#  ('Ilya Rocha', 4, 'El enigma de la despedida'),
#  ('Wan Borges', 6, 'El despertar de el vuelo'),
#  ('Bianca Ortega', 2, 'El arco iris de la verdad'),
#  ('Ilya Rocha', 4, 'La rebelión de el fuego'),
#  ('Theresa Olivares', 6, 'El resurgimiento de el laberinto'),
#  ('Quintus Wu', 4, 'El vuelo de la noche'),
#  ('Umberto Almeida', 3, 'El espejismo de la fuga'),
#  ('Valeria Teixeira', 3, 'El misterio de el legado'),
#  ('Hiroko Dutta', 4, 'El vuelo de el amor'),
#  ('Yasmin Rodriguez', 5, 'El viajero de el ángel'),
#  ('Zafar Nogueira', 6, 'El caballero de la maraña'),
#  ('Wilhelmina Inácio', 3, 'La travesura de la escuela'),
#  ('Leonardo Etxebarria', 6, 'La trampa de la bienvenida'),
#  ('Zoya Martinez', 2, 'La batalla de la venganza'),
#  ('Lakshmi Montenegro', 3, 'El resurgimiento de el laberinto'),
#  ('Wilhelmina Nguyen', 3, 'El hechizo de el pacto'),
#  ('Zara Nogueira', 2, 'La búsqueda de la nube'),
#  ('Valeria Inácio', 4, 'El secreto de el río'),
#  ('Leonardo Etxebarria', 6, 'El renacimiento de la estrella'),
#  ('Xavier Dutta', 4, 'La rebelión de el adiós'),
#  ('Zoya Gomes', 4, 'La senda de la sonrisa'),
#  ('Pilar Gao', 4, 'La senda de la princesa'),
#  ('Patricia Fernandes', 5, 'La resurrección de la reina'),
#  ('Omar Mendes', 5, 'La rebelión de el adiós'),
#  ('Giovanni Queiroz', 3, 'La llave de la cárcel'),
#  ('Jin Etxebarria', 3, 'El destino de la caída')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT t_a.nombre
#
#   FROM director t_d
#
#   INNER JOIN pelicula t_p ON
#              t_d.id_director = t_p.id_director
#
#   INNER JOIN actor_participa_en_pelicula t_ap ON
#              t_p.id_pelicula = t_ap.id_pelicula
#
#   INNER JOIN actor t_a ON
#              t_ap.id_actor = t_a.id_actor
#
#   LEFT JOIN
#     (
#         SELECT
#             id_actor,
#             id_director
#         FROM
#             actor_participa_en_pelicula ap
#         INNER JOIN
#             pelicula p ON ap.id_pelicula = p.id_pelicula
#         WHERE
#             id_director != 1
#     ) out ON t_ap.id_actor = out.id_actor
#
#   WHERE
#     t_d.id_director = 1 AND
#     out.id_director IS NULL
#   GROUP BY
#     t_a.nombre
#
# --Se crea la tabla combinación de director, película, actor y actor participa en película
# --se crea la tabla combinación de película, actor y actor participa en película cuando el id_directors es distinto de 1
# --En la primera tabla de combinación, si el id_diretcro corresponde a 1 y lo demás, en la segunda tabla combianción, el id_director no se encuentra
# --Se agrupa por combinación de el campo nombre_de_actor y se selecciona este mismo
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH
# --Crear una tabla con los nombres e id de los actores sin premios
# tabla1 AS(
#     SELECT nombre, actor.id_actor
#     FROM actor
#     FULL JOIN premio_mejor_actor p_ma ON
#        actor.id_actor = p_ma.id_actor
#     WHERE p_ma IS NULL
# ),
# --Juntamos la tabla anterior con actor_participa_en_pelicula
# tabla2 AS(
#     SELECT tabla1.nombre, a_pp.id_pelicula
#     FROM tabla1
#     INNER JOIN actor_participa_en_pelicula a_pp ON
#         tabla1.id_actor = a_pp.id_actor
# ),
# --Juntamos la tabla anterior con las peliculas para obtener sus nombres
# tabla3 AS(
#     SELECT tabla2.nombre, pp.nombre AS nombre_pelicula, pp.id_director
#     FROM tabla2
#     INNER JOIN pelicula pp ON
#         tabla2.id_pelicula = pp.id_pelicula
# ),
# --Juntamos la tabla anterior con los directores de dichas peliculas para obtener sus nombres
# tabla4 AS(
#     SELECT tabla3.nombre, tabla3.nombre_pelicula, tabla3.id_director, dir.nombre AS nombre_director
#     FROM tabla3
#     INNER JOIN director dir ON
#         tabla3.id_director = dir.id_director
# ),
# --Tabla auxiliar para obtener el número de peliculas de un director
# tabla5 AS(
#     SELECT DISTINCT tabla4.id_director, COUNT(DISTINCT pp.id_pelicula) AS peliculas_del_director
#     FROM tabla4
#     INNER JOIN pelicula pp ON
#         pp.id_director = tabla4.id_director
# 	GROUP BY tabla4.id_director
# ),
# --Tabla auxiliar para obtener el número de premios de un director
# tabla6 AS(
#     SELECT DISTINCT tabla4.id_director, COUNT(DISTINCT pmd.anio) AS premios_del_director
#     FROM tabla4
#     INNER JOIN premio_mejor_director pmd ON
#         pmd.id_director = tabla4.id_director
# 	GROUP BY tabla4.id_director
# ),
# --Juntamos la tabla 4 con la cantidad de premios de cada director
# tabla7 AS(
#     SELECT tabla4.nombre, tabla4.nombre_pelicula, tabla4.nombre_director, tabla4.id_director, COALESCE(tabla6.premios_del_director, 0) AS numero_de_premios_del_director
#     FROM tabla4
# 	LEFT JOIN tabla6 ON
# 		tabla4.id_director = tabla6.id_director
# ),
# --Juntamos la tabla anterior con la cantidad de peliculas de cada director
# tabla8 AS(
#     SELECT tabla7.nombre, tabla7.nombre_pelicula, tabla7.nombre_director, COALESCE(tabla5.peliculas_del_director, 0) AS numero_de_peliculas_del_director, tabla7.numero_de_premios_del_director
#     FROM tabla7
# 	LEFT JOIN tabla5 ON
# 		tabla5.id_director = tabla7.id_director
# )
# --Print
# SELECT * from tabla8
# Out:
#  * postgresql://postgres:***@localhost:5432/my_BD
# 399 rows affected.
# [('Pilar Almeida', 'El despertar de la paz', 'Fabiana Gao', 2, 0),
#  ('Rosa Joaquim', 'El último viaje de el abismo', 'Quintus Xia', 1, 0),
#  ('Rosa Joaquim', 'El regreso de el vuelo', 'Elif Inácio', 3, 0),
#  ('Isa Inácio', 'El secreto de la cueva', 'Quintus Zapata', 2, 0),
#  ('Darya Urbina', 'El caballero de la caverna', 'Valeria Lima', 4, 1),
#  ('Darya Urbina', 'El pacto de la expedición', 'Qiu Carvalho', 4, 0),
#  ('Omar Mendes', 'El hechizo de el grito', 'Leonardo Duarte', 2, 0),
#  ('Omar Mendes', 'La travesía sin retorno de el jardín', 'Qiu Carvalho', 4, 0),
#  ('Omar Mendes', 'La rebelión de el adiós', 'Bianca Estevez', 2, 0),
#  ('Omar Mendes', 'La batalla de el océano', 'Genghis Lopez', 4, 1),
#  ('Omar Mendes', 'La estrella fugaz de la esperanza', 'Patricia Henriquez', 1, 0),
#  ('Ximena Uchoa', 'El viaje de el camino', 'Ursula Lopez', 2, 0),
#  ('Ximena Uchoa', 'La profecía de el misterio', 'Zoya Vargas', 2, 0),
#  ('Ximena Uchoa', 'El despertar de la aldea', 'Nina Tan', 4, 0),
#  ('Ximena Uchoa', 'El regreso de la noche', 'Fadhila Tan', 3, 0),
#  ('Hiroko Nguyen', 'La doncella de la corrupción', 'Wilhelmina Janssen', 2, 1),
#  ('Hiroko Nguyen', 'El bosque encantado de el amor', 'Hanako Zambrano', 4, 0),
#  ('Hiroko Nguyen', 'La profecía de la huida', 'Umar Ortega', 1, 0),
#  ('Hiroko Nguyen', 'El canto de sirena de la oscuridad', 'Giovanni Velez', 1, 0),
#  ('Hiroko Nguyen', 'La leyenda de la pesadilla', 'Fabiana Mendes', 3, 0),
#  ('Isa Hernandez', 'La estirpe de el descubrimiento', 'Rashid Esteves', 3, 0),
#  ('Isa Hernandez', 'El arco iris de la magia', 'Leticia Correia', 2, 1),
#  ('Isa Hernandez', 'El secreto oscuro de la travesía', 'Dmitri Joaquim', 1, 0),
#  ('Isa Hernandez', 'El lamento de el enigma', 'Isa Ramos', 1, 0),
#  ('Isa Hernandez', 'El eclipse de la ciudad', 'Nina Tan', 4, 0),
#  ('Isa Hernandez', 'El misterio de el encuentro', 'Katarina Jimenez', 4, 1),
#  ('Jasmin Janssen', 'La conquista de la luz', 'Elif Yamamoto', 1, 0),
#  ('Jasmin Janssen', 'La profecía de el destino', 'Tatiana Alvarez', 2, 0),
#  ('Yusef Kawaguchi', 'El lamento de la flor', 'Alessandro Fernandes', 3, 0),
#  ('Yusef Kawaguchi', 'La metamorfosis de el abismo', 'Natalia Watanabe', 2, 0),
#  ('Yusef Kawaguchi', 'El vuelo de la noche', 'Samir Nguyen', 2, 0),
#  ('Javier Yan', 'El camino hacia la estrella fugaz', 'Samir Correia', 2, 0),
#  ('Javier Yan', 'La historia de la clave', 'Rosa Sousa', 3, 1),
#  ('Leonardo Bianchi', 'La profecía de el destino', 'Tatiana Alvarez', 2, 0),
#  ('Leonardo Bianchi', 'La cripta de la nube', 'Alessandro Bianchi', 1, 0),
#  ('Darya Fernandes', 'La profecía de la huida', 'Umar Ortega', 1, 0),
#  ('Darya Fernandes', 'La doncella de la redención', 'Hiroko Ferreira', 2, 0),
#  ('Javier Jimenez', 'El misterio de el encuentro', 'Katarina Jimenez', 4, 1),
#  ('Javier Jimenez', 'La fortuna de la pasión', 'Gustavo Kawaguchi', 4, 0),
#  ('Javier Jimenez', 'La venganza de la sombra', 'Quentin Lopes', 1, 1),
#  ('Umberto Montenegro', 'El prisionero de el grito', 'Zafar Velez', 2, 0),
#  ('Patricia Fernandes', 'La estirpe de el descubrimiento', 'Rashid Esteves', 3, 0),
#  ('Patricia Fernandes', 'La resurrección de la reina', 'Hiroko Vieira', 2, 0),
#  ('Patricia Fernandes', 'La danza de el sueño', 'Darya Urbina', 2, 2),
#  ('Patricia Fernandes', 'El pacto de la expedición', 'Qiu Carvalho', 4, 0),
#  ('Patricia Fernandes', 'La llegada de la luz', 'Yuri Watanabe', 2, 0),
#  ('Zara Watanabe', 'El vuelo mágico de el amor', 'Beatriz Quintana', 2, 0),
#  ('Zoya Martinez', 'La batalla de la venganza', 'Mehmet Montenegro', 1, 1),
#  ('Zoya Martinez', 'La profecía de la cripta', 'Fabiana Mendes', 3, 0),
#  ('Mikhail Montenegro', 'El amanecer de la caverna', 'Leonardo Ferreira', 2, 0),
#  ('Mikhail Montenegro', 'La misión de el laberinto', 'Ursula Tan', 4, 1),
#  ('Mikhail Montenegro', 'La travesía del océano de el adiós', 'Elif Inácio', 3, 0),
#  ('Nina Olivares', 'La danza macabra de el tesoro', 'Genghis Sousa', 3, 0),
#  ('Nina Olivares', 'El eclipse de el jardín', 'Fadhila Tan', 3, 0),
#  ('Lakshmi Ferreira', 'El refugio de la cascada', 'Khaled Vieira', 1, 1),
#  ('Lakshmi Ferreira', 'La venganza de el enigma', 'Abdullah Sousa', 1, 1),
#  ('Elena Pacheco', 'El castillo de el unicornio', 'Leticia Correia', 2, 1),
#  ('Elena Pacheco', 'El regreso de la noche', 'Fadhila Tan', 3, 0),
#  ('Elena Pacheco', 'La llegada de la luz', 'Yuri Watanabe', 2, 0),
#  ('Elena Pacheco', 'El caballero de el sol', 'Zara Vargas', 1, 0),
#  ('Parvati Esteves', 'El tesoro de el pacto', 'Bianca Estevez', 2, 0),
#  ('Pilar Pereira', 'El príncipe de la academia', 'Qiu Carvalho', 4, 0),
#  ('Pilar Pereira', 'La venganza de el enigma', 'Abdullah Sousa', 1, 1),
#  ('Pilar Pereira', 'La rebelión de la sonrisa', 'Nina Yamamoto', 4, 0),
#  ('Pilar Pereira', 'El prisionero de la bestia', 'Valentina Rodriguez', 2, 0),
#  ('Pilar Pereira', 'El pacto de la expedición', 'Qiu Carvalho', 4, 0),
#  ('Pilar Pereira', 'El secreto oscuro de el árbol', 'Ursula Tan', 4, 1),
#  ('Pilar Pereira', 'La travesura de el ángel', 'Rashid Yilmaz', 2, 0),
#  ('Darya Pacheco', 'El caballero de la caverna', 'Valeria Lima', 4, 1),
#  ('Darya Pacheco', 'La cripta de la nube', 'Alessandro Bianchi', 1, 0),
#  ('Ximena Zhang', 'El último viaje de el ángel', 'Valentina Vieira', 2, 0),
#  ('Ximena Zhang', 'La venganza de la sombra', 'Quentin Lopes', 1, 1),
#  ('Ximena Zhang', 'El laberinto de la ley', 'Zara Vargas', 1, 0),
#  ('Quintus Qian', 'El laberinto de el muro', 'Aarav Abadi', 5, 0),
#  ('Vivek Figueiredo', 'La metamorfosis de el rincón', 'Katarina Zhang', 2, 1),
#  ('Vivek Figueiredo', 'El caballero de la heroína', 'Mikhail Lopez', 2, 0),
#  ('Qiu Almeida', 'El castillo de el amor', 'Natalia Borges', 1, 0),
#  ('Qiu Almeida', 'El grito de el dragón', 'Katarina Duarte', 2, 0),
#  ('Qiu Almeida', 'El hechizo de el pacto', 'Samir Dutta', 2, 0),
#  ('Mehmet Olivares', 'El misterio de el secreto', 'Genghis Hidalgo', 2, 0),
#  ('Mehmet Olivares', 'El arco iris de la magia', 'Leticia Correia', 2, 1),
#  ('Mehmet Olivares', 'El hechizo de el pacto', 'Samir Dutta', 2, 0),
#  ('Wilhelmina Abadi', 'El viajero de la corrupción', 'Theresa Yamamoto', 2, 0),
#  ('Wilhelmina Abadi', 'La senda de el hechicero', 'Hanako Zambrano', 4, 0),
#  ('Theresa Kawaguchi', 'El último viaje de el ángel', 'Valentina Vieira', 2, 0),
#  ('Xin Ramos', 'El lamento de la flor', 'Alessandro Fernandes', 3, 0),
#  ('Xin Ramos', 'El caballero de la heroína', 'Mikhail Lopez', 2, 0),
#  ('Tatjana Pacheco', 'La estirpe de el vuelo', 'Umberto Olivares', 2, 1),
#  ('Tatjana Pacheco', 'El lamento de el enigma', 'Isa Ramos', 1, 0),
#  ('Natalia Velez', 'La cripta de el jardín', 'Pilar Lopes', 3, 0),
#  ('Natalia Velez', 'El caballero de la heroína', 'Mikhail Lopez', 2, 0),
#  ('Natalia Velez', 'El vuelo de la resistencia', 'Mikhail Lopez', 2, 0),
#  ('Natalia Velez', 'La danza macabra de la flor', 'Khaled Rocha', 3, 0),
#  ('Natalia Velez', 'La batalla de el héroe', 'Quentin Goncalves', 3, 0),
#  ('Bianca Nogueira', 'El espejismo de la caída', 'Aarav Lopes', 2, 0),
#  ('Bianca Nogueira', 'El arco iris de la montaña', 'Umberto Diniz', 1, 1),
#  ('Bianca Nogueira', 'El lamento de el enigma', 'Isa Ramos', 1, 0),
#  ('Yusef Yan', 'La historia de la clave', 'Rosa Sousa', 3, 1),
#  ('Yusef Yan', 'El refugio de la cueva', 'Alessandro Janssen', 2, 0),
#  ('Aarav Velez', 'Las aventuras de la tormenta', 'Mehmet Goncalves', 3, 1),
#  ('Aarav Velez', 'La llegada de el renacer', 'Xavier Figueiredo', 2, 0),
#  ('Mikhail Fernandes', 'El cuento de hadas de el renacimiento', 'Katarina Zhang', 2, 1),
#  ('Darya Figueiredo', 'La travesía de la desgracia', 'Ilya Vargas', 2, 0),
#  ('Darya Figueiredo', 'El destino de el camino', 'Fabiana Mendes', 3, 0),
#  ('Darya Figueiredo', 'La danza macabra de la flor', 'Khaled Rocha', 3, 0),
#  ('Darya Figueiredo', 'La senda de el hechicero', 'Hanako Zambrano', 4, 0),
#  ('Javier Quintana', 'La cripta de el jardín', 'Pilar Lopes', 3, 0),
#  ('Javier Quintana', 'El lamento de la guerra', 'Javier Montenegro', 2, 0),
#  ('Hiroko Dutta', 'La invasión de el lamento', 'Khaled Lima', 5, 0),
#  ('Hiroko Dutta', 'El amanecer de la academia', 'Yuri Almeida', 3, 0),
#  ('Hiroko Dutta', 'El vuelo de el amor', 'Aarav Xia', 1, 0),
#  ('Hiroko Dutta', 'La maldición del vampiro de la estrella fugaz', 'Quentin Goncalves', 3, 0),
#  ('Tatjana Oliveira', 'El destino de la magia', 'Chen Dutta', 2, 0),
#  ('Tatjana Oliveira', 'El descubrimiento de el perdón', 'Tatiana Alvarez', 2, 0),
#  ('Tatjana Oliveira', 'La maldición de el sol', 'Khaled Barros', 4, 0),
#  ('Rania Kumar', 'El viaje de el peligro', 'Omar Diniz', 3, 0),
#  ('Rania Kumar', 'El resurgimiento de el laberinto', 'Vivek Hernandez', 1, 1),
#  ('Rania Kumar', 'El caballero de la espada', 'Quintus Zapata', 2, 0),
#  ('Fadhila Ortega', 'El amanecer de el castillo', 'Wan Hernandez', 3, 0),
#  ('Fadhila Ortega', 'El destino de el sol', 'Valentina Vieira', 2, 0),
#  ('Fadhila Ortega', 'La trampa de la bienvenida', 'Valentina Rodriguez', 2, 0),
#  ('Fadhila Ortega', 'La fortuna de la pasión', 'Gustavo Kawaguchi', 4, 0),
#  ('Orhan Kumar', 'El viajero de la ola', 'Khaled Lima', 5, 0),
#  ('Orhan Kumar', 'La llegada de el renacer', 'Xavier Figueiredo', 2, 0),
#  ('Gustavo Pacheco', 'La rebelión de la espada', 'Wan Figueiredo', 1, 0),
#  ('Gustavo Pacheco', 'El regreso de la prisión', 'Samir Quintana', 2, 0),
#  ('Gustavo Pacheco', 'El pacto de la expedición', 'Qiu Carvalho', 4, 0),
#  ('Zafar Olivares', 'El resurgimiento de la leyenda', 'Katarina Rodriguez', 3, 0),
#  ('Zafar Olivares', 'La cripta de el viajero', 'Parvati Ferreira', 2, 0),
#  ('Jin Etxebarria', 'El resurgimiento de la leyenda', 'Katarina Rodriguez', 3, 0),
#  ('Jin Etxebarria', 'El destino de la caída', 'Genghis Pereira', 1, 0),
#  ('Jin Etxebarria', 'El misterio de el legado', 'Elif Sousa', 2, 1),
#  ('Yusef Oliveira', 'El camino hacia la huida', 'Ilya Santana', 1, 1),
#  ('Salim Lima', 'La conquista de la estrella', 'Genghis Lopez', 4, 1),
#  ('Irina Ueno', 'La metamorfosis de el rincón', 'Katarina Zhang', 2, 1),
#  ('Isa Kawaguchi', 'El laberinto de la corrupción', 'Rosa Pereira', 3, 0),
#  ('Isa Kawaguchi', 'El regreso de el vuelo', 'Elif Inácio', 3, 0),
#  ('Elena Petrov', 'El destino de la magia', 'Chen Dutta', 2, 0),
#  ('Elena Petrov', 'La resurrección de la puerta', 'Mehmet Goncalves', 3, 1),
#  ('Elena Petrov', 'El vuelo de la resistencia', 'Mikhail Lopez', 2, 0),
#  ('Elena Petrov', 'El lamento de el cielo', 'Rania Ivanov', 1, 0),
#  ('Orhan Sousa', 'La llegada de la luz', 'Yuri Watanabe', 2, 0),
#  ('Orhan Sousa', 'La fuga de la compañía', 'Theresa Qian', 2, 1),
#  ('Valentina Teles', 'La trampa de el horizonte', 'Irina Dutta', 1, 0),
#  ('Zoya Sousa', 'La conquista de la luz', 'Elif Yamamoto', 1, 0),
#  ('Zoya Sousa', 'La trampa de la bienvenida', 'Valentina Rodriguez', 2, 0),
#  ('Zoya Sousa', 'La estirpe de la maraña', 'Xavier Tan', 2, 0),
#  ('Giovanni Lopes', 'El vuelo de la ciudad', 'Gustavo Kawaguchi', 4, 0),
#  ('Giovanni Lopes', 'La resurrección de la aventura', 'Ursula Lopez', 2, 0),
#  ('Giovanni Lopes', 'El misterio de el legado', 'Elif Sousa', 2, 1),
#  ('Xavier Dutta', 'La rebelión de el adiós', 'Salim Etxebarria', 2, 1),
#  ('Xavier Dutta', 'La conquista de la luz', 'Elif Yamamoto', 1, 0),
#  ('Xavier Dutta', 'El caballero de la guerra', 'Leticia Uchoa', 2, 1),
#  ('Xavier Dutta', 'El caballero de la maraña', 'Xavier Figueiredo', 2, 0),
#  ('Genghis Figueiredo', 'La estirpe de la profecía', 'Salim Etxebarria', 2, 1),
#  ('Genghis Figueiredo', 'La batalla de el océano', 'Genghis Lopez', 4, 1),
#  ('Chidike Wu', 'El último viaje de la pasión', 'Natalia Hernandez', 2, 0),
#  ('Yuri Santana', 'La rebelión de el fuego', 'Wan Lopes', 2, 0),
#  ('Yuri Santana', 'La senda de el hechicero', 'Hanako Zambrano', 4, 0),
#  ('Yuri Santana', 'La conquista de la revelación', 'Mehmet Petrov', 3, 0),
#  ('Chiyoko Santana', 'El arco iris de la oscuridad', 'Aarav Abadi', 5, 0),
#  ('Chiyoko Santana', 'El lamento de el unicornio', 'Wan Lopes', 2, 0),
#  ('Chiyoko Santana', 'La invasión de el mago', 'Rania Yan', 3, 1),
#  ('Chiyoko Santana', 'El grito de el dragón', 'Katarina Duarte', 2, 0),
#  ('Chiyoko Santana', 'El caballero de la guerra', 'Leticia Uchoa', 2, 1),
#  ('Chiyoko Santana', 'El prisionero de el sueño', 'Jin Santana', 1, 0),
#  ('Lakshmi Diniz', 'El tesoro escondido de el hechicero', 'Valeria Lima', 4, 1),
#  ('Lakshmi Diniz', 'El regreso de el vuelo', 'Elif Inácio', 3, 0),
#  ('Rosa Ortega', 'La batalla de el océano', 'Genghis Lopez', 4, 1),
#  ('Rosa Ortega', 'El prisionero de el sacrificio', 'Rania Yan', 3, 1),
#  ('Rosa Ortega', 'El cuento de hadas de el puente', 'Rania Yan', 3, 1),
#  ('Chidike Teixeira', 'El despertar de el vuelo', 'Natalia Watanabe', 2, 0),
#  ('Mikhail Zhang', 'La profecía de el misterio', 'Zoya Vargas', 2, 0),
#  ('Mikhail Zhang', 'La misión de la leyenda', 'Patricia Qian', 3, 0),
#  ('Wilhelmina Lopez', 'La resurrección de la puerta', 'Mehmet Goncalves', 3, 1),
#  ('Rashid Olivares', 'El canto de sirena de la estrella fugaz', 'Chidike Alvarez', 1, 0),
#  ('Elif Vieira', 'El grito de la noche', 'Chen Esteves', 2, 0),
#  ('Elif Vieira', 'La profecía de la cripta', 'Fabiana Mendes', 3, 0),
#  ('Leticia Velez', 'El refugio de la cascada', 'Khaled Vieira', 1, 1),
#  ('Leticia Velez', 'La tormenta de la heroína', 'Theresa Yamamoto', 2, 0),
#  ('Leticia Velez', 'El bosque encantado de la cueva', 'Leticia Yilmaz', 2, 0),
#  ('Giovanni Velez', 'La resurrección de el ángel', 'Chiyoko Lopez', 1, 0),
#  ('Giovanni Velez', 'El ritual de el valle', 'Valeria Lima', 4, 1),
#  ('Giovanni Velez', 'La danza macabra de el sueño', 'Leticia Oliveira', 2, 0),
#  ('Genghis Urbina', 'El bosque encantado de la guerra', 'Patricia Qian', 3, 0),
#  ('Genghis Urbina', 'El ritual de la guerra', 'Javier Urbina', 2, 0),
#  ('Genghis Urbina', 'La batalla de el puente', 'Jin Alvarez', 3, 0),
#  ('Genghis Urbina', 'El prisionero de el valle', 'Nina Vieira', 1, 0),
#  ('Elena Ortega', 'La conquista de la esperanza', 'Mehmet Petrov', 3, 0),
#  ('Elena Ortega', 'La maldición de el sol', 'Khaled Barros', 4, 0),
#  ('Aarav Carvalho', 'La llegada de la luz', 'Yuri Watanabe', 2, 0),
#  ('Aarav Carvalho', 'El renacimiento de la pesadilla', 'Nina Yamamoto', 4, 0),
#  ('Nadia Pacheco', 'La travesía del océano de el río', 'Bianca Watanabe', 1, 0),
#  ('Nadia Pacheco', 'El refugio de la cueva', 'Alessandro Janssen', 2, 0),
#  ('Nadia Pacheco', 'El tesoro de el horizonte', 'Katarina Duarte', 2, 0),
#  ('Wang Nunes', 'El cuento de hadas de el peligro', 'Kamala Teles', 2, 1),
#  ('Wang Nunes', 'La resurrección de la reina', 'Hiroko Vieira', 2, 0),
#  ('Wang Nunes', 'El prisionero de el valle', 'Nina Vieira', 1, 0),
#  ('Wang Nunes', 'La venganza de la luz', 'Katarina Rodriguez', 3, 0),
#  ('Wang Nunes', 'La cripta de la desgracia', 'Rashid Esteves', 3, 0),
#  ('Wang Kumar', 'La metamorfosis de el abismo', 'Natalia Watanabe', 2, 0),
#  ('Wang Kumar', 'La senda de el hechicero', 'Hanako Zambrano', 4, 0),
#  ('Dmitri Lopez', 'El despertar de el vuelo', 'Natalia Watanabe', 2, 0),
#  ('Leonardo Lima', 'El misterio de el secreto', 'Genghis Hidalgo', 2, 0),
#  ('Leonardo Lima', 'La rebelión de la sonrisa', 'Nina Yamamoto', 4, 0),
#  ('Leonardo Lima', 'El tesoro escondido de el hechicero', 'Valeria Lima', 4, 1),
#  ('Tatiana Qian', 'El destino de la magia', 'Chen Dutta', 2, 0),
#  ('Tatiana Qian', 'El espejismo de la fuga', 'Katarina Teles', 1, 1),
#  ('Zoya Gomes', 'El renacimiento de la neblina', 'Valentina Uchoa', 1, 0),
#  ('Zoya Gomes', 'El lamento de el unicornio', 'Wan Lopes', 2, 0),
#  ('Zoya Gomes', 'La senda de la sonrisa', 'Samir Dutta', 2, 0),
#  ('Zoya Gomes', 'El eclipse de la redención', 'Zoya Diniz', 1, 0),
#  ('Isa Nguyen', 'El regreso de la gruta', 'Chen Iglesias', 3, 0),
#  ('Yuri Iglesias', 'La estirpe de la leyenda', 'Genghis Xu', 1, 1),
#  ('Yuri Iglesias', 'La rebelión de el adiós', 'Bianca Estevez', 2, 0),
#  ('Beatriz Zhang', 'El guardián de el sapo', 'Beatriz Quintana', 2, 0),
#  ('Beatriz Zhang', 'El cuento de hadas de el peligro', 'Kamala Teles', 2, 1),
#  ('Beatriz Zhang', 'El misterio de la huida', 'Katarina Jimenez', 4, 1),
#  ('Beatriz Zhang', 'El lamento de la guerra', 'Javier Montenegro', 2, 0),
#  ('Ursula Pacheco', 'La danza macabra de la soledad', 'Gustavo Kawaguchi', 4, 0),
#  ('Ursula Pacheco', 'El resurgimiento de el laberinto', 'Hiroko Ferreira', 2, 0),
#  ('Umar Oliveira', 'El lamento de la traición', 'Yuri Almeida', 3, 0),
#  ('Umar Oliveira', 'El vuelo de el amor', 'Aarav Xia', 1, 0),
#  ('Kamala Goncalves', 'La leyenda de el sueño', 'Genghis Lopez', 4, 1),
#  ('Kamala Goncalves', 'El laberinto de el castillo', 'Tatiana Ivanov', 1, 0),
#  ('Zoya Figueiredo', 'El caballero de el sol', 'Zara Vargas', 1, 0),
#  ('Lakshmi Yan', 'El lamento de la flor', 'Alessandro Fernandes', 3, 0),
#  ('Lakshmi Yan', 'El lamento de el enigma', 'Isa Ramos', 1, 0),
#  ('Elif Hidalgo', 'La fuga de la compañía', 'Theresa Qian', 2, 1),
#  ('Elif Hidalgo', 'La batalla de el misterio', 'Genghis Lopez', 4, 1),
#  ('Elif Hidalgo', 'El príncipe de la caverna', 'Ursula Tan', 4, 1),
#  ('Wilhelmina Xia', 'La rebelión de la espada', 'Wan Figueiredo', 1, 0),
#  ('Wilhelmina Xia', 'El arco iris de la montaña', 'Umberto Diniz', 1, 1),
#  ('Kamala Diniz', 'El renacimiento de la neblina', 'Valentina Uchoa', 1, 0),
#  ('Kamala Diniz', 'El caballero de la guerra', 'Leticia Uchoa', 2, 1),
#  ('Kamala Diniz', 'La doncella de la redención', 'Hiroko Ferreira', 2, 0),
#  ('Fabiana Henriquez', 'La cripta de la nube', 'Alessandro Bianchi', 1, 0),
#  ('Fabiana Henriquez', 'El regreso de el abismo', 'Pilar Tan', 1, 0),
#  ('Javier Jimenez', 'La redención de la caverna', 'Katarina Gao', 2, 0),
#  ('Javier Jimenez', 'La leyenda perdida de el rincón', 'Mikhail Bianchi', 1, 0),
#  ('Javier Jimenez', 'El amanecer de la bestia', 'Tatiana Zhang', 1, 0),
#  ('Wilhelmina Nguyen', 'La llave de la cárcel', 'Katarina Jimenez', 4, 1),
#  ('Wilhelmina Nguyen', 'El viajero de el destino', 'Ximena Mendes', 2, 0),
#  ('Wilhelmina Nguyen', 'El hechizo de el pacto', 'Samir Dutta', 2, 0),
#  ('Quintus Inácio', 'El misterio de la huida', 'Katarina Jimenez', 4, 1),
#  ('Quintus Inácio', 'El lamento de el unicornio', 'Wan Lopes', 2, 0),
#  ('Quintus Inácio', 'El laberinto de la ley', 'Zara Vargas', 1, 0),
#  ('Quintus Inácio', 'El camino hacia la huida', 'Ilya Santana', 1, 1),
#  ('Orhan Olivares', 'La doncella de la ola', 'Elif Sousa', 2, 1),
#  ('Orhan Olivares', 'La estirpe de la leyenda', 'Genghis Xu', 1, 1),
#  ('Orhan Olivares', 'El ritual de la guerra', 'Javier Urbina', 2, 0),
#  ('Orhan Olivares', 'El refugio de la cueva', 'Alessandro Janssen', 2, 0),
#  ('Xavier Estevez', 'La profecía de la huida', 'Umar Ortega', 1, 0),
#  ('Xavier Estevez', 'El arco iris de la montaña', 'Umberto Diniz', 1, 1),
#  ('Xavier Estevez', 'El laberinto de el laberinto', 'Valentina Zapata', 2, 1),
#  ('Valeria Teixeira', 'El grito de el dragón', 'Katarina Duarte', 2, 0),
#  ('Valeria Teixeira', 'El laberinto de el susurro', 'Jin Alvarez', 3, 0),
#  ('Valeria Teixeira', 'El misterio de el legado', 'Elif Sousa', 2, 1),
#  ('Dmitri Uchoa', 'La venganza de el volcán', 'Zafar Velez', 2, 0),
#  ('Dmitri Uchoa', 'La búsqueda de la nube', 'Khaled Urbina', 2, 0),
#  ('Dmitri Uchoa', 'El destino de el amor', 'Ursula Tan', 4, 1),
#  ('Oscar Nogueira', 'El caballero de la maraña', 'Xavier Figueiredo', 2, 0),
#  ('Nadia Rodriguez', 'La senda de la sonrisa', 'Samir Dutta', 2, 0),
#  ('Nadia Rodriguez', 'La fortuna de la esperanza', 'Jasmin Teles', 1, 0),
#  ('Gustavo Cruz', 'La fortuna de la noche', 'Yuri Watanabe', 2, 0),
#  ('Valentina Lopes', 'El caballero de la maraña', 'Xavier Figueiredo', 2, 0),
#  ('Gustavo Abadi', 'El espejismo de la profecía', 'Jin Alvarez', 3, 0),
#  ('Zoya Yilmaz', 'La estirpe de el descubrimiento', 'Rashid Esteves', 3, 0),
#  ('Zoya Yilmaz', 'El laberinto de la ley', 'Zara Vargas', 1, 0),
#  ('Zoya Yilmaz', 'El misterio de el laberinto', 'Quentin Joaquim', 1, 0),
#  ('Alessandro Joaquim', 'El caballero de el león', 'Parvati Esteves', 3, 0),
#  ('Alessandro Joaquim', 'La misión de la leyenda', 'Patricia Qian', 3, 0),
#  ('Alessandro Nunes', 'La invasión de el guardián', 'Jin Queiroz', 1, 0),
#  ('Alessandro Nunes', 'La búsqueda de el viajero', 'Hiroko Vieira', 2, 0),
#  ('Alessandro Nunes', 'La historia de la clave', 'Rosa Sousa', 3, 1),
#  ('Alessandro Lima', 'El regreso de el abismo', 'Pilar Tan', 1, 0),
#  ('Rania Cruz', 'El laberinto de el susurro', 'Jin Alvarez', 3, 0),
#  ('Rania Cruz', 'El regreso de el jardín', 'Leticia Ivanov', 2, 0),
#  ('Nadia Wu', 'La leyenda de el sueño', 'Genghis Lopez', 4, 1),
#  ('Nadia Wu', 'La llegada de el laberinto', 'Khaled Lima', 5, 0),
#  ('Nadia Wu', 'El caballero de la espada', 'Aarav Lopes', 2, 0),
#  ('Pilar Sousa', 'La cripta de la paz', 'Vivek Janssen', 1, 0),
#  ('Pilar Sousa', 'El misterio de el legado', 'Elif Sousa', 2, 1),
#  ('Pilar Sousa', 'La leyenda de la pesadilla', 'Fabiana Mendes', 3, 0),
#  ('Vivek Jimenez', 'El lamento de la amistad', 'Samir Correia', 2, 0),
#  ('Vivek Jimenez', 'La llave de la cárcel', 'Katarina Jimenez', 4, 1),
#  ('Vivek Jimenez', 'El viaje de la luna', 'Alessandro Fernandes', 3, 0),
#  ('Vivek Jimenez', 'El secreto oscuro de el tesoro', 'Khaled Barros', 4, 0),
#  ('Vivek Jimenez', 'El castillo de el hechizo', 'Natalia Yilmaz', 2, 0),
#  ('Vivek Jimenez', 'El grito de el castillo', 'Beatriz Mendes', 1, 0),
#  ('Katarina Janssen', 'El viaje de el camino', 'Ursula Lopez', 2, 0),
#  ('Katarina Janssen', 'La batalla de el puente', 'Jin Alvarez', 3, 0),
#  ('Yuri Yamamoto', 'El amanecer de la academia', 'Yuri Almeida', 3, 0),
#  ('Yuri Yamamoto', 'El destino de el amor', 'Ursula Tan', 4, 1),
#  ('Yuri Yamamoto', 'El lamento de la amistad', 'Samir Esteves', 2, 0),
#  ('Yuri Yamamoto', 'La maldición del vampiro de la estrella fugaz', 'Quentin Goncalves', 3, 0),
#  ('Hanako Xu', 'La cripta de el jardín', 'Pilar Lopes', 3, 0),
#  ('Hanako Xu', 'El vuelo mágico de el amor', 'Beatriz Quintana', 2, 0),
#  ('Natalia Oliveira', 'El tesoro de el pacto', 'Bianca Estevez', 2, 0),
#  ('Natalia Oliveira', 'La estirpe de la leyenda', 'Genghis Xu', 1, 1),
#  ('Natalia Oliveira', 'El pacto de la expedición', 'Qiu Carvalho', 4, 0),
#  ('Orhan Santana', 'La venganza de el volcán', 'Zafar Velez', 2, 0),
#  ('Orhan Santana', 'El lamento de el enigma', 'Isa Ramos', 1, 0),
#  ('Chidike Santana', 'La doncella de la corrupción', 'Wilhelmina Janssen', 2, 1),
#  ('Chidike Santana', 'El lamento de la guerra', 'Javier Montenegro', 2, 0),
#  ('Chidike Santana', 'El vuelo mágico de el amor', 'Beatriz Quintana', 2, 0),
#  ('Ilya Rocha', 'El arco iris de la verdad', 'Omar Diniz', 3, 0),
#  ('Ilya Rocha', 'La rebelión de el fuego', 'Wan Lopes', 2, 0),
#  ('Ilya Rocha', 'El enigma de la despedida', 'Pilar Lopes', 3, 0),
#  ('Ilya Rocha', 'La danza macabra de el tesoro', 'Genghis Sousa', 3, 0),
#  ('Rashid Xavier', 'El secreto de la perdición', 'Valeria Lima', 4, 1),
#  ('Rashid Xavier', 'El secreto oscuro de el tesoro', 'Khaled Barros', 4, 0),
#  ('Rashid Xavier', 'El último viaje de el abismo', 'Quintus Xia', 1, 0),
#  ('Rashid Xavier', 'La batalla de el puente', 'Jin Alvarez', 3, 0),
#  ('Rashid Xavier', 'El lamento de la bruja', 'Alessandro Janssen', 2, 0),
#  ('Rashid Xavier', 'La travesía del océano de el adiós', 'Elif Inácio', 3, 0),
#  ('Mehmet Etxebarria', 'El castillo de el hechizo', 'Natalia Yilmaz', 2, 0),
#  ('Mehmet Etxebarria', 'La resurrección de la aventura', 'Ursula Lopez', 2, 0),
#  ('Mehmet Etxebarria', 'El lamento de la guerra', 'Javier Montenegro', 2, 0),
#  ('Mehmet Etxebarria', 'La danza macabra de el tesoro', 'Genghis Sousa', 3, 0),
#  ('Mehmet Etxebarria', 'La profecía de la verdad', 'Umar Pacheco', 1, 0),
#  ('Yasmin Rodriguez', 'La búsqueda de la nube', 'Khaled Urbina', 2, 0),
#  ('Yasmin Rodriguez', 'El viajero de el ángel', 'Umberto Olivares', 2, 1),
#  ('Yasmin Rodriguez', 'El grito de el amor', 'Rosa Sousa', 3, 1),
#  ('Yasmin Rodriguez', 'El renacimiento de la prisión', 'Javier Xia', 1, 0),
#  ('Yasmin Rodriguez', 'La leyenda de la pesadilla', 'Fabiana Mendes', 3, 0),
#  ('Nina Nguyen', 'El destino de la caída', 'Genghis Pereira', 1, 0),
#  ('Nina Nguyen', 'La batalla de la venganza', 'Mehmet Montenegro', 1, 1),
#  ('Khaled Wu', 'El vuelo mágico de la espada mágica', 'Rosa Pereira', 3, 0),
#  ('Khaled Wu', 'La danza macabra de la flor', 'Khaled Rocha', 3, 0),
#  ('Khaled Wu', 'El canto de sirena de la oscuridad', 'Giovanni Velez', 1, 0),
#  ('Theresa Rocha', 'La doncella de el sueño', 'Xin Vargas', 1, 0),
#  ('Elif Diniz', 'La resurrección de la aventura', 'Ursula Lopez', 2, 0),
#  ('Elif Diniz', 'La travesía del océano de el río', 'Bianca Watanabe', 1, 0),
#  ('Elif Diniz', 'El caballero de la maraña', 'Xavier Figueiredo', 2, 0),
#  ('Elif Diniz', 'La misión de la leyenda', 'Patricia Qian', 3, 0),
#  ('Zara Nogueira', 'La redención de la caverna', 'Katarina Gao', 2, 0),
#  ('Zara Nogueira', 'La búsqueda de la nube', 'Khaled Urbina', 2, 0),
#  ('Beatriz Queiroz', 'La búsqueda de el viajero', 'Hiroko Vieira', 2, 0),
#  ('Beatriz Queiroz', 'El laberinto de el susurro', 'Jin Alvarez', 3, 0),
#  ('Beatriz Queiroz', 'El tesoro escondido de la aventura', 'Khaled Lima', 5, 0),
#  ('Han Teles', 'La fortuna de la noche', 'Yuri Watanabe', 2, 0),
#  ('Han Teles', 'El laberinto de la trampa', 'Valentina Rodriguez', 1, 0),
#  ('Han Teles', 'La redención de el héroe', 'Patricia Qian', 3, 0),
#  ('Han Teles', 'El caballero de el sol', 'Zara Vargas', 1, 0),
#  ('Leonardo Gao', 'El regreso de el sol', 'Ximena Mendes', 2, 0),
#  ('Leonardo Gao', 'La misión de el laberinto', 'Ursula Tan', 4, 1),
#  ('Leonardo Gao', 'El regreso de la noche', 'Fadhila Tan', 3, 0),
#  ('Theresa Rodriguez', 'El lamento de el unicornio', 'Wan Lopes', 2, 0),
#  ('Theresa Rodriguez', 'El regreso de el vuelo', 'Elif Inácio', 3, 0),
#  ('Theresa Rodriguez', 'La profecía de la verdad', 'Umar Pacheco', 1, 0),
#  ('Theresa Rodriguez', 'La travesura de el ángel', 'Rashid Yilmaz', 2, 0),
#  ('Aarav Olivares', 'La leyenda de la pesadilla', 'Fabiana Mendes', 3, 0),
#  ('Pilar Yilmaz', 'La rebelión de la espada', 'Wan Figueiredo', 1, 0),
#  ('Pilar Yilmaz', 'La senda de la princesa', 'Chen Iglesias', 3, 0),
#  ('Zoya Ramos', 'La llegada de la luz', 'Yuri Watanabe', 2, 0),
#  ('Umberto Zambrano', 'El lamento de el río', 'Jin Hernandez', 2, 0),
#  ('Umberto Zambrano', 'La rebelión de el adiós', 'Salim Etxebarria', 2, 1),
#  ('Umberto Zambrano', 'La profecía de la oscuridad', 'Yusef Nguyen', 1, 0),
#  ('Umberto Zambrano', 'El bosque encantado de la traición', 'Aarav Abadi', 5, 0),
#  ('Umberto Zambrano', 'La doncella de la redención', 'Hiroko Ferreira', 2, 0),
#  ('Oscar Gomes', 'El regreso de la fortuna', 'Javier Montenegro', 2, 0),
#  ('Oscar Gomes', 'El guardián de la bailarina', 'Leticia Uchoa', 2, 1),
#  ('Bianca Ortega', 'El arco iris de la verdad', 'Omar Diniz', 3, 0),
#  ('Bianca Ortega', 'El vuelo mágico de la caída', 'Qiu Carvalho', 4, 0),
#  ('Lakshmi Montenegro', 'El resurgimiento de el laberinto', 'Vivek Hernandez', 1, 1),
#  ('Lakshmi Montenegro', 'El tesoro escondido de la aventura', 'Khaled Lima', 5, 0),
#  ('Lakshmi Montenegro', 'La leyenda perdida de el sacrificio', 'Khaled Rocha', 3, 0),
#  ('Darya Abadi', 'El refugio de la cascada', 'Khaled Vieira', 1, 1),
#  ('Darya Abadi', 'El pacto de la luna', 'Samir Esteves', 2, 0),
#  ('Sakura Nogueira', 'La metamorfosis de el abismo', 'Natalia Watanabe', 2, 0),
#  ('Sakura Nogueira', 'La danza macabra de la flor', 'Khaled Rocha', 3, 0),
#  ('Quentin Jimenez', 'La conquista de la luz', 'Elif Yamamoto', 1, 0),
#  ('Quentin Jimenez', 'La batalla de el puente', 'Jin Alvarez', 3, 0),
#  ('Zafar Nogueira', 'El viaje de el camino', 'Ursula Lopez', 2, 0),
#  ('Zafar Nogueira', 'Las aventuras de la tormenta', 'Mehmet Goncalves', 3, 1),
#  ('Zafar Nogueira', 'La fortuna de la noche', 'Yuri Watanabe', 2, 0),
#  ('Zafar Nogueira', 'El vuelo mágico de la espada mágica', 'Rosa Pereira', 3, 0),
#  ('Zafar Nogueira', 'El destino de el amor', 'Ursula Tan', 4, 1),
#  ('Zafar Nogueira', 'El caballero de la maraña', 'Xavier Figueiredo', 2, 0),
#  ('Theresa Olivares', 'La leyenda de el sueño', 'Genghis Lopez', 4, 1),
#  ('Theresa Olivares', 'El resurgimiento de el laberinto', 'Vivek Hernandez', 1, 1),
#  ('Theresa Olivares', 'El lamento de el unicornio', 'Wan Lopes', 2, 0),
#  ('Theresa Olivares', 'El eclipse de la guerra', 'Elena Lima', 1, 0),
#  ('Theresa Olivares', 'El eclipse de la redención', 'Zoya Diniz', 1, 0),
#  ('Theresa Olivares', 'La maldición de el sol', 'Khaled Barros', 4, 0),
#  ('Rania Estevez', 'La batalla de el renacimiento', 'Chen Iglesias', 3, 0),
#  ('Sakura Carvalho', 'La cripta de el viajero', 'Parvati Ferreira', 2, 0),
#  ('Sakura Carvalho', 'La travesía sin retorno de el jardín', 'Qiu Carvalho', 4, 0),
#  ('Sakura Carvalho', 'La profecía de el misterio', 'Zoya Vargas', 2, 0),
#  ('Natalia Vargas', 'La doncella de el sueño', 'Xin Vargas', 1, 0),
#  ('Natalia Vargas', 'La resurrección de el ángel', 'Chiyoko Lopez', 1, 0),
#  ('Xavier Zambrano', 'El resurgimiento de la leyenda', 'Katarina Rodriguez', 3, 0),
#  ('Xavier Zambrano', 'Las aventuras de la tormenta', 'Mehmet Goncalves', 3, 1),
#  ('Xavier Zambrano', 'La venganza de la luz', 'Katarina Rodriguez', 3, 0),
#  ('Giovanni Estevez', 'La invasión de el renacimiento', 'Isa Almeida', 1, 0),
#  ('Giovanni Estevez', 'La profecía de la aventura', 'Leonardo Duarte', 2, 0),
#  ('Giovanni Estevez', 'El laberinto de el muro', 'Aarav Abadi', 5, 0),
#  ('Rosa Watanabe', 'La batalla de el océano', 'Genghis Lopez', 4, 1)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
