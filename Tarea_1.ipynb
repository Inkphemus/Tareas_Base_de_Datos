# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Tomás Ramdohr
# * Sebastián Cornejo
# * Fabian Clavijo

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\t6974\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (2.0.25)
# Requirement already satisfied: sqlparse in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\t6974\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\t6974\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\t6974\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in c:\users\t6974\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\t6974\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\t6974\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\t6974\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\t6974\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\t6974\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\t6974\anaconda3\lib\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:poto@localhost:5432/Tarea_1
# Out:
# env: DATABASE_URL=postgresql://postgres:poto@localhost:5432/Tarea_1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='Tarea_1',
   password="poto"
)

print(conn)
# Out:
# <connection object at 0x000002C41918D360; dsn: 'user=postgres password=xxx dbname=Tarea_1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (id_director INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_director))
# Out:
# (psycopg2.errors.DuplicateTable) la relación «director» ya existe
#
# [SQL: CREATE TABLE director (id_director INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (id_actor INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_actor))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «actor» ya existe
#
# [SQL: CREATE TABLE actor (id_actor INT GENERATED ALWAYS AS IDENTITY,
# nombre VARCHAR(45),
# edad INT,
# PRIMARY KEY(id_actor))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (id_pelicula INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# nombre VARCHAR(45),
# genero VARCHAR(45),
# duracion INT,
# fecha_publicacion DATE,
# PRIMARY KEY (id_pelicula),
# FOREIGN KEY (id_director) REFERENCES director(id_director))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «pelicula» ya existe
#
# [SQL: CREATE TABLE pelicula (id_pelicula INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# nombre VARCHAR(45),
# genero VARCHAR(45),
# duracion INT,
# fecha_publicacion DATE,
# PRIMARY KEY (id_pelicula),
# FOREIGN KEY (id_director) REFERENCES director(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (id_actor INT,
#                                           id_pelicula INT,
#                                           PRIMARY KEY (id_actor, id_pelicula),
#                                           FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#                                           FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «actor_participa_en_pelicula» ya existe
#
# [SQL: CREATE TABLE actor_participa_en_pelicula (id_actor INT,
#                                           id_pelicula INT,
#                                           PRIMARY KEY (id_actor, id_pelicula),
#                                           FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#                                           FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_director) REFERENCES director(id_director))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_director» ya existe
#
# [SQL: CREATE TABLE premio_mejor_director (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_director INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_director) REFERENCES director(id_director))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_actor INT,
# anio INT,
# PRIMARY KEY (id_premio),
# FOREIGN KEY(id_actor) REFERENCES actor(id_actor))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_actor» ya existe
#
# [SQL: CREATE TABLE premio_mejor_actor (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_actor INT,
# anio INT,
# PRIMARY KEY (id_premio),
# FOREIGN KEY(id_actor) REFERENCES actor(id_actor))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_pelicula INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_pelicula) REFERENCES pelicula(id_pelicula))
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_pelicula» ya existe
#
# [SQL: CREATE TABLE premio_mejor_pelicula (id_premio INT GENERATED ALWAYS AS IDENTITY,
# id_pelicula INT,
# anio INT,
# PRIMARY KEY (id_premio), FOREIGN KEY(id_pelicula) REFERENCES pelicula(id_pelicula))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date

#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()
premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {301: {'año': 1993, 'director': 236, 'genero': 'Acción', 'cast': [237], 'mejor pelicula': 'no'}, 302: {'año': 2019, 'director': 278, 'genero': 'Terror', 'cast': [401, 347, 320], 'mejor pelicula': 'no'}, 303: {'año': 1982, 'director': 317, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 304: {'año': 2001, 'director': 362, 'genero': 'Drama', 'cast': [307, 265], 'mejor pelicula': 'no'}, 305: {'año': 1972, 'director': 284, 'genero': 'Misterio', 'cast': [263], 'mejor pelicula': 'no'}, 306: {'año': 2002, 'director': 366, 'genero': 'Comedia', 'cast': [220], 'mejor pelicula': 'no'}, 307: {'año': 2003, 'director': 387, 'genero': 'Romance', 'cast': [363], 'mejor pelicula': 'no'}, 308: {'año': 1979, 'director': 362, 'genero': 'Drama', 'cast': [372], 'mejor pelicula': 'no'}, 309: {'año': 2018, 'director': 294, 'genero': 'Acción', 'cast': [203], 'mejor pelicula': 'no'}, 310: {'año': 2021, 'director': 234, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 311: {'año': 2022, 'director': 399, 'genero': 'Animación', 'cast': [256, 285], 'mejor pelicula': 'no'}, 312: {'año': 1992, 'director': 298, 'genero': 'Western', 'cast': [241, 354, 316], 'mejor pelicula': 'no'}, 313: {'año': 2015, 'director': 400, 'genero': 'Musical', 'cast': [353, 308], 'mejor pelicula': 'no'}, 314: {'año': 1991, 'director': 208, 'genero': 'Western', 'cast': [331, 255], 'mejor pelicula': 'no'}, 315: {'año': 2017, 'director': 317, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 316: {'año': 1992, 'director': 270, 'genero': 'Romance', 'cast': [395], 'mejor pelicula': 'no'}, 317: {'año': 1979, 'director': 255, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 318: {'año': 1982, 'director': 258, 'genero': 'Drama', 'cast': [252], 'mejor pelicula': 'no'}, 319: {'año': 2020, 'director': 218, 'genero': 'Aventura', 'cast': [254, 211], 'mejor pelicula': 'no'}, 320: {'año': 2008, 'director': 243, 'genero': 'Documental', 'cast': [333, 298], 'mejor pelicula': 'no'}, 321: {'año': 1993, 'director': 267, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 322: {'año': 1995, 'director': 280, 'genero': 'Western', 'cast': [277, 261], 'mejor pelicula': 'no'}, 323: {'año': 1976, 'director': 375, 'genero': 'Fantasía', 'cast': [237], 'mejor pelicula': 'no'}, 324: {'año': 2003, 'director': 307, 'genero': 'Musical', 'cast': [284], 'mejor pelicula': 'no'}, 325: {'año': 1998, 'director': 250, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 326: {'año': 2019, 'director': 226, 'genero': 'Suspense', 'cast': [333, 390], 'mejor pelicula': 'no'}, 327: {'año': 2012, 'director': 335, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 328: {'año': 2003, 'director': 219, 'genero': 'Documental', 'cast': [312, 363, 213], 'mejor pelicula': 'no'}, 329: {'año': 2005, 'director': 236, 'genero': 'Animación', 'cast': [304, 309], 'mejor pelicula': 'no'}, 330: {'año': 1975, 'director': 311, 'genero': 'Documental', 'cast': [354, 337, 251], 'mejor pelicula': 'no'}, 331: {'año': 1962, 'director': 231, 'genero': 'Comedia', 'cast': [284], 'mejor pelicula': 'no'}, 332: {'año': 1967, 'director': 372, 'genero': 'Terror', 'cast': [203], 'mejor pelicula': 'no'}, 333: {'año': 2019, 'director': 337, 'genero': 'Acción', 'cast': [354, 221, 329, 319], 'mejor pelicula': 'no'}, 334: {'año': 2003, 'director': 273, 'genero': 'Ciencia ficción', 'cast': [], 'mejor pelicula': 'no'}, 335: {'año': 2006, 'director': 241, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 336: {'año': 2021, 'director': 356, 'genero': 'Romance', 'cast': [346, 283], 'mejor pelicula': 'no'}, 337: {'año': 1994, 'director': 296, 'genero': 'Acción', 'cast': [289], 'mejor pelicula': 'no'}, 338: {'año': 1972, 'director': 278, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 339: {'año': 2019, 'director': 255, 'genero': 'Animación', 'cast': [381, 266], 'mejor pelicula': 'no'}, 340: {'año': 2007, 'director': 225, 'genero': 'Aventura', 'cast': [229, 256], 'mejor pelicula': 'no'}, 341: { ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 89
#      87         continue
#      88 elif eleccion_premio == "mejor actor":
# ---> 89     if premios_info[pelicula_al_azar]["cast"] != []:
#      90         actor = random.choice(premios_info[pelicula_al_azar]["cast"])
#      91         año = premios_info[pelicula_al_azar]["año"]
#
# KeyError: 278

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre
# FROM pelicula
# WHERE fecha_publicacion > '2023-04-12'
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 4 rows affected.
# [('Las aventuras de la desgracia',),
#  ('El laberinto de el atardecer',),
#  ('La estrella fugaz de el rey',),
#  ('La redención de la noche',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre, fecha_publicacion
# FROM pelicula
# WHERE fecha_publicacion >= '2023-01-01'
#     AND fecha_publicacion < '2024-01-01'
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 5 rows affected.
# [('La historia de la oscuridad', datetime.date(2023, 2, 8)),
#  ('Las aventuras de la desgracia', datetime.date(2023, 12, 28)),
#  ('El laberinto de el atardecer', datetime.date(2023, 6, 18)),
#  ('La estrella fugaz de el rey', datetime.date(2023, 5, 26)),
#  ('La redención de la noche', datetime.date(2023, 12, 3))]

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre
# FROM actor
# WHERE id_actor IN(
#     SELECT id_actor
#     FROM actor_participa_en_pelicula
#     WHERE id_pelicula IN(
#         SELECT id_pelicula
#         FROM pelicula
#         WHERE genero = 'Comedia'
#     )
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 43 rows affected.
# [('Wang Barros',),
#  ('Sakura Lopes',),
#  ('Gustavo Kumar',),
#  ('Mina Iglesias',),
#  ('Orhan Olivares',),
#  ('Ursula Ramos',),
#  ('Valentina Kawaguchi',),
#  ('Xin Duarte',),
#  ('Ilya Qian',),
#  ('Yuri Yilmaz',),
#  ('Jin Janssen',),
#  ('Chidike Gao',),
#  ('Dmitri Tan',),
#  ('Yuri Fernandes',),
#  ('Katarina Nunes',),
#  ('Tatiana Abadi',),
#  ('Samir Oliveira',),
#  ('Genghis Henriquez',),
#  ('Chiyoko Velez',),
#  ('Darius Xu',),
#  ('Genghis Montenegro',),
#  ('Darius Lopes',),
#  ('Mehmet Borges',),
#  ('Khaled Correia',),
#  ('Kamala Figueiredo',),
#  ('Ilya Watanabe',),
#  ('Mehmet Nunes',),
#  ('Zara Velez',),
#  ('Rania Urbina',),
#  ('Nina Zhang',),
#  ('Nina Ferreira',),
#  ('Katarina Zambrano',),
#  ('Parvati Nunes',),
#  ('Emiko Ferreira',),
#  ('Darya Borges',),
#  ('Samir Abadi',),
#  ('Aarav Watanabe',),
#  ('Kamala Velez',),
#  ('Rania Lopez',),
#  ('Mina Cruz',),
#  ('Qiu Lopes',),
#  ('Tatiana Teixeira',),
#  ('Aarav Diniz',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [raw]
# %%sql
# SELECT genero, COUNT(pelicula)
# FROM pelicula
# GROUP BY genero
# ORDER BY COUNT (pelicula) DESC;

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT * FROM(
#     SELECT pelicula.nombre, COUNT(actor.nombre) AS cuenta
#     FROM pelicula, actor_participa_en_pelicula, actor
#     WHERE pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
#         AND actor.id_actor = actor_participa_en_pelicula.id_actor
#     GROUP BY pelicula.nombre
#     ORDER BY COUNT(actor.nombre) DESC)
# WHERE cuenta > 1
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 148 rows affected.
# [('La batalla de la espada mágica', 7),
#  ('La leyenda perdida de la guerra', 6),
#  ('La escalada de la revelación', 5),
#  ('La travesía de el explorador', 5),
#  ('La búsqueda de la esperanza', 5),
#  ('La travesura de el valle', 5),
#  ('La historia de el amor', 5),
#  ('La venganza de la revelación', 5),
#  ('El viaje de la misión', 5),
#  ('El destino de el sueño', 4),
#  ('El último viaje de la heroína', 4),
#  ('El príncipe de la aventura', 4),
#  ('El destino de la escuela', 4),
#  ('La odisea de el cielo', 4),
#  ('La búsqueda del tesoro de el valle', 4),
#  ('La historia de el laberinto', 4),
#  ('El despertar de la batalla', 4),
#  ('El arco iris de el mito', 4),
#  ('El renacimiento de el encuentro', 4),
#  ('El hechizo de la tormenta', 4),
#  ('El guardián de la sombra', 4),
#  ('La leyenda de la estrella', 4),
#  ('La llave de la venganza', 4),
#  ('La maldición de la muralla', 4),
#  ('La travesía del océano de la senda', 4),
#  ('La redención de el mar', 4),
#  ('La cripta de la espada mágica', 4),
#  ('El grito de el camino', 4),
#  ('El prisionero de el monstruo', 3),
#  ('La redención de el susurro', 3),
#  ('La venganza de la estrella', 3),
#  ('La resurrección de el encuentro', 3),
#  ('El regreso de la pesadilla', 3),
#  ('La resurrección de la oscuridad', 3),
#  ('La travesía sin retorno de el sacrificio', 3),
#  ('La rebelión de la magia', 3),
#  ('El castillo de la promesa', 3),
#  ('La travesía sin retorno de el encuentro', 3),
#  ('El canto de sirena de la aldea', 3),
#  ('El grito de el legado', 3),
#  ('El resurgimiento de el unicornio', 3),
#  ('La búsqueda de el sapo', 3),
#  ('El amanecer de la neblina', 3),
#  ('El canto de sirena de el perdón', 3),
#  ('La metamorfosis de la clave', 3),
#  ('El canto de sirena de el tesoro', 3),
#  ('El misterio de la corona', 3),
#  ('La cripta de la gárgola', 3),
#  ('El eclipse de el guardián', 3),
#  ('El viajero de la fortuna', 3),
#  ('La estirpe de la pesadilla', 3),
#  ('La fortuna de la noche', 3),
#  ('El príncipe de la travesía', 3),
#  ('La búsqueda del tesoro de la prisión', 3),
#  ('El canto de sirena de la bestia', 3),
#  ('El despertar de la estrella fugaz', 3),
#  ('El refugio de el hechicero', 3),
#  ('El enigma de el trono', 3),
#  ('La odisea de la luz', 3),
#  ('El destino de la heroína', 3),
#  ('El arco iris de el lamento', 3),
#  ('El grito de la libertad', 3),
#  ('El descubrimiento de el puente', 3),
#  ('La redención de la pesadilla', 3),
#  ('La rebelión de la estrella', 3),
#  ('El prisionero de el sol', 3),
#  ('El hechizo de la bruja', 3),
#  ('El laberinto de la fuga', 3),
#  ('El ritual de el descubrimiento', 3),
#  ('El guardián de la leyenda', 2),
#  ('El ritual de la sirena', 2),
#  ('El ritual de la ciudad', 2),
#  ('El renacimiento de el héroe', 2),
#  ('La maldición del vampiro de la pesadilla', 2),
#  ('El pacto de la magia', 2),
#  ('La travesía del océano de el río', 2),
#  ('El amanecer de la espada', 2),
#  ('El viajero de el amor', 2),
#  ('El laberinto de la heroína', 2),
#  ('La danza de el viaje', 2),
#  ('La leyenda de la bruma', 2),
#  ('La leyenda de la caza', 2),
#  ('El tesoro escondido de el faro', 2),
#  ('El renacimiento de la espada', 2),
#  ('La travesía de la senda', 2),
#  ('El enigma de el océano', 2),
#  ('El vuelo de la princesa', 2),
#  ('El hechizo de la magia', 2),
#  ('La trampa de la traición', 2),
#  ('La misión de la sombra', 2),
#  ('La maldición de la nube', 2),
#  ('La fuente de la pesadilla', 2),
#  ('El pacto de la reina', 2),
#  ('La danza de la pesadilla', 2),
#  ('La danza macabra de el susurro', 2),
#  ('El viajero de la guerra', 2),
#  ('La búsqueda del tesoro de el muro', 2),
#  ('La senda de el muro', 2),
#  ('El camino hacia la despedida', 2),
#  ('La llave de la ola', 2),
#  ('La maldición de la tierra', 2),
#  ('La cripta de la maraña', 2),
#  ('El bosque encantado de la sombra', 2),
#  ('La leyenda de el descubrimiento', 2),
#  ('El misterio de el guardián', 2),
#  ('El tesoro de el amor', 2),
#  ('La tormenta de el castillo', 2),
#  ('El secreto oscuro de la oscuridad', 2),
#  ('El último viaje de el cielo', 2),
#  ('El último viaje de la profecía', 2),
#  ('Las aventuras de la luz', 2),
#  ('La doncella de el amor', 2),
#  ('La sombra de la prisión', 2),
#  ('El viaje de la academia', 2),
#  ('La travesía de el destino', 2),
#  ('La danza macabra de la espada', 2),
#  ('Las aventuras de la desgracia', 2),
#  ('El viaje de la aventura', 2),
#  ('El príncipe de la luna', 2),
#  ('La estirpe de el laberinto', 2),
#  ('El cuento de hadas de la gárgola', 2),
#  ('El vuelo mágico de el bosque', 2),
#  ('La trampa de el mago', 2),
#  ('El enigma de el muro', 2),
#  ('La rebelión de el abismo', 2),
#  ('La invasión de la flor', 2),
#  ('La metamorfosis de el enigma', 2),
#  ('El viajero de la soledad', 2),
#  ('El misterio de el atardecer', 2),
#  ('La cripta de la despedida', 2),
#  ('El resurgimiento de el laberinto', 2),
#  ('El príncipe de la corrupción', 2),
#  ('La sombra de el león', 2),
#  ('El vuelo de la alianza', 2),
#  ('La llegada de el viaje', 2),
#  ('El secreto de la libertad', 2),
#  ('El arco iris de el ángel', 2),
#  ('El secreto oscuro de el bosque', 2),
#  ('El viaje de la alianza', 2),
#  ('La leyenda perdida de la despedida', 2),
#  ('El resurgimiento de la revelación', 2),
#  ('La travesía del océano de la aventura', 2),
#  ('La danza macabra de la pasión', 2),
#  ('El viaje de la oscuridad', 2),
#  ('El ritual de el faro', 2),
#  ('El príncipe de la pesadilla', 2),
#  ('La historia de el camino', 2),
#  ('La trampa de la reina', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT t_p.nombre AS nombre_pelicula,
#            MAX(t_a.edad) AS edad_actor_mayor,
#            MIN(t_a.edad) AS edad_actor_menor
#
#   FROM pelicula t_p
#
#   INNER JOIN actor_participa_en_pelicula t_ap ON
#              t_p.id_pelicula = t_ap.id_pelicula
#   INNER JOIN actor t_a ON
#              t_ap.id_actor = t_a.id_actor
#
#     GROUP BY t_p.nombre
#     ORDER BY ABS(MAX(t_a.edad) - MIN(t_a.edad))
#     DESC
#     LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 1 rows affected.
# [('El grito de el camino', 66, 5)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT anio
# FROM premio_mejor_pelicula
# WHERE id_pelicula =
# (SELECT id_pelicula
#  FROM pelicula
#  ORDER BY duracion
#  LIMIT 1)
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH
# tabla1 AS(
#     SELECT t_a.nombre, t_a.id_actor, COUNT(DISTINCT t_p.id_director) AS dir_num
#     FROM director t_d
#     INNER JOIN pelicula t_p ON
#         t_d.id_director = t_p.id_director
#     INNER JOIN actor_participa_en_pelicula t_ap ON
#         t_p.id_pelicula = t_ap.id_pelicula
#     INNER JOIN actor t_a ON
#         t_ap.id_actor = t_a.id_actor
#     GROUP BY t_a.id_actor
#     HAVING COUNT(DISTINCT t_p.id_director) > 1
# ),
# tabla2 AS(
#     SELECT pp.nombre AS nombre_de_una_pelicula, tabla1.id_actor
#     FROM tabla1
#     INNER JOIN actor_participa_en_pelicula app ON
#         tabla1.id_actor = app.id_actor
#     INNER JOIN pelicula pp ON
#         app.id_pelicula = pp.id_pelicula
# ),
# tabla3 AS(
#     SELECT tabla1.nombre, tabla1.dir_num, tabla2.nombre_de_una_pelicula
#     FROM tabla1
#     INNER JOIN tabla2 ON
#         tabla1.id_actor = tabla2.id_actor
# )
# SELECT * FROM tabla3
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 450 rows affected.
# [('Patricia Montenegro', 3, 'El hechizo de la bruja'),
#  ('Giovanni Almeida', 3, 'El hechizo de la tormenta'),
#  ('Fabiana Abadi', 2, 'La venganza de el misterio'),
#  ('Lakshmi Ortega', 2, 'La búsqueda de la esperanza'),
#  ('Sakura Goncalves', 5, 'El príncipe de la corrupción'),
#  ('Yuri Yamamoto', 3, 'El vuelo de el héroe'),
#  ('Katarina Nunes', 2, 'La redención de el mar'),
#  ('Darius Xu', 8, 'La leyenda de la estrella'),
#  ('Pilar Jimenez', 5, 'El canto de sirena de el perdón'),
#  ('Han Fernandes', 2, 'El hechizo de la batalla'),
#  ('Irina Esteves', 4, 'El vuelo de la alianza'),
#  ('Ursula Ramos', 2, 'El viaje de la misión'),
#  ('Wan Hernandez', 5, 'El enigma de el trono'),
#  ('Wan Hernandez', 5, 'El renacimiento de la espada'),
#  ('Mina Cruz', 3, 'El amanecer de la neblina'),
#  ('Vivek Carvalho', 5, 'El canto de sirena de la aldea'),
#  ('Darius Gao', 4, 'La fortuna de la noche'),
#  ('Emiko Rocha', 3, 'El arco iris de la magia'),
#  ('Tatjana Yamamoto', 3, 'El secreto oscuro de la oscuridad'),
#  ('Nina Zhang', 6, 'El ritual de el descubrimiento'),
#  ('Qiu Lopes', 4, 'El grito de la libertad'),
#  ('Qiu Diniz', 4, 'El cuento de hadas de la gárgola'),
#  ('Gustavo Kumar', 5, 'El bosque encantado de la sombra'),
#  ('Yusef Ivanov', 3, 'La danza de el viaje'),
#  ('Genghis Henriquez', 3, 'El ritual de la sirena'),
#  ('Mikhail Santos', 4, 'La sombra de el unicornio'),
#  ('Mehmet Rocha', 2, 'El ritual de la ciudad'),
#  ('Dmitri Tan', 3, 'El viaje de la academia'),
#  ('Yuri Ortega', 4, 'El vuelo de la ley'),
#  ('Sakura Iglesias', 3, 'La resurrección de el encuentro'),
#  ('Irina Martinez', 3, 'El refugio de la aventura'),
#  ('Dmitri Tan', 3, 'El viaje de la alianza'),
#  ('Zara Gao', 2, 'El camino hacia el viaje'),
#  ('Ilya Qian', 5, 'La redención de el susurro'),
#  ('Yuri Fernandes', 4, 'El camino hacia la despedida'),
#  ('Mikhail Santos', 4, 'La invasión de la flor'),
#  ('Xin Duarte', 6, 'El canto de sirena de la bestia'),
#  ('Oscar Montenegro', 5, 'La historia de el laberinto'),
#  ('Xin Duarte', 6, 'El misterio de el guardián'),
#  ('Zara Velez', 2, 'La odisea de el viaje'),
#  ('Katarina Ramos', 3, 'El pacto de la reina'),
#  ('Emiko Ferreira', 4, 'El príncipe de la luna'),
#  ('Ximena Joaquim', 3, 'El pacto de la magia'),
#  ('Kamala Gao', 5, 'La maldición de el puente'),
#  ('Quintus Yamamoto', 3, 'La maldición de la profecía'),
#  ('Zara Velez', 2, 'El misterio de la corona'),
#  ('Rosa Janssen', 3, 'El despertar de la estrella fugaz'),
#  ('Ilya Watanabe', 3, 'La cripta de la despedida'),
#  ('Chiyoko Henriquez', 4, 'La maldición del vampiro de la cascada'),
#  ('Jin Janssen', 3, 'El destino de la heroína'),
#  ('Darius Lopes', 5, 'El resurgimiento de el unicornio'),
#  ('Wilhelmina Lima', 4, 'El canto de sirena de el perdón'),
#  ('Rosa Martinez', 4, 'El último viaje de el cielo'),
#  ('Salim Ueno', 3, 'El eclipse de el unicornio'),
#  ('Ximena Joaquim', 3, 'El príncipe de la corrupción'),
#  ('Yasmin Kawaguchi', 4, 'La travesía de la senda'),
#  ('Darius Qian', 4, 'El resurgimiento de la huida'),
#  ('Jin Zapata', 3, 'La senda de el muro'),
#  ('Darius Xu', 8, 'La venganza de la revelación'),
#  ('Kamala Figueiredo', 5, 'La llegada de el viaje'),
#  ('Wang Barros', 2, 'La leyenda perdida de la guerra'),
#  ('Yusef Etxebarria', 3, 'El despertar de la estrella fugaz'),
#  ('Wan Hernandez', 5, 'La maldición del vampiro de la pesadilla'),
#  ('Yuri Yilmaz', 3, 'La tormenta de el castillo'),
#  ('Irina Gao', 4, 'La travesura de el valle'),
#  ('Bianca Alvarez', 5, 'La leyenda de el sacrificio'),
#  ('Han Dutta', 2, 'El regreso de la pesadilla'),
#  ('Elif Jimenez', 4, 'La travesía de el explorador'),
#  ('Patricia Montenegro', 3, 'La travesura de la gárgola'),
#  ('Nina Ferreira', 2, 'La redención de la pesadilla'),
#  ('Gustavo Kumar', 5, 'La danza de la pesadilla'),
#  ('Xin Duarte', 6, 'La cripta de la despedida'),
#  ('Nina Kawaguchi', 2, 'El refugio de el grito'),
#  ('Rania Lopez', 4, 'La resurrección de la oscuridad'),
#  ('Yuri Yamamoto', 3, 'La senda de el muro'),
#  ('Mina Iglesias', 4, 'La venganza de la revelación'),
#  ('Darius Lopes', 5, 'El secreto de la libertad'),
#  ('Quintus Yamamoto', 3, 'La redención de el mar'),
#  ('Chidike Gao', 3, 'La leyenda perdida de la guerra'),
#  ('Pilar Zapata', 2, 'La odisea de el cielo'),
#  ('Ursula Yilmaz', 3, 'El amanecer de la espada'),
#  ('Giovanni Queiroz', 2, 'El viajero de la soledad'),
#  ('Kamala Joaquim', 2, 'El enigma de el océano'),
#  ('Wilhelmina Lima', 4, 'El grito de el camino'),
#  ('Irina Abadi', 4, 'La travesía de el explorador'),
#  ('Katarina Zambrano', 3, 'La escalada de la revelación'),
#  ('Omar Hernandez', 7, 'El refugio de el hechicero'),
#  ('Beatriz Martinez', 2, 'La maldición de la muralla'),
#  ('Chidike Tan', 2, 'El tesoro escondido de el faro'),
#  ('Yuri Yamamoto', 3, 'La rebelión de la estrella'),
#  ('Mina Iglesias', 4, 'La metamorfosis de la clave'),
#  ('Parvati Nunes', 3, 'El príncipe de la aventura'),
#  ('Theresa Alvarez', 2, 'El bosque encantado de la flor'),
#  ('Khaled Correia', 3, 'La batalla de la academia'),
#  ('Zara Martinez', 2, 'La historia de el amor'),
#  ('Gustavo Kumar', 5, 'El eclipse de el guardián'),
#  ('Nina Zhang', 6, 'El laberinto de la fuga'),
#  ('Darius Gao', 4, 'El último viaje de la profecía'),
#  ('Sakura Goncalves', 5, 'El arco iris de el mito'),
#  ('Aarav Diniz', 3, 'El misterio de la corona'),
#  ('Mina Iglesias', 4, 'La historia de el puente'),
#  ('Sakura Iglesias', 3, 'El destino de el sueño'),
#  ('Wan Ueno', 3, 'El eclipse de el guardián'),
#  ('Gustavo Kumar', 5, 'La danza macabra de la revelación'),
#  ('Ilya Diniz', 3, 'El renacimiento de el encuentro'),
#  ('Jin Janssen', 3, 'La leyenda perdida de la guerra'),
#  ('Leticia Kawaguchi', 2, 'La trampa de la traición'),
#  ('Hiroko Velez', 2, 'El descubrimiento de el puente'),
#  ('Han Zapata', 3, 'El arco iris de el sueño'),
#  ('Emiko Ferreira', 4, 'La sombra de la prisión'),
#  ('Emiko Rocha', 3, 'El hechizo de la magia'),
#  ('Mikhail Santos', 4, 'El descubrimiento de el puente'),
#  ('Sakura Goncalves', 5, 'La metamorfosis de la clave'),
#  ('Tatiana Yamamoto', 4, 'El resurgimiento de la aventura'),
#  ('Kamala Figueiredo', 5, 'El laberinto de el atardecer'),
#  ('Khaled Vieira', 7, 'El descubrimiento de el puente'),
#  ('Gustavo Kumar', 5, 'Las aventuras de la leyenda'),
#  ('Pilar Jimenez', 5, 'El viajero de la soledad'),
#  ('Ilya Watanabe', 3, 'La cripta de la gárgola'),
#  ('Ilya Diniz', 3, 'La venganza de la revelación'),
#  ('Irina Abadi', 4, 'El prisionero de el monstruo'),
#  ('Mina Cruz', 3, 'El príncipe de la aventura'),
#  ('Han Dutta', 2, 'El secreto oscuro de la aventura'),
#  ('Lakshmi Henriquez', 3, 'El hechizo de la tormenta'),
#  ('Tatiana Yamamoto', 4, 'El misterio de el río'),
#  ('Rania Ramos', 2, 'El canto de sirena de la aldea'),
#  ('Zoya Ferreira', 2, 'La travesía sin retorno de el sacrificio'),
#  ('Elif Alvarez', 2, 'El destino de la heroína'),
#  ('Jin Fernandes', 2, 'El viajero de el amor'),
#  ('Genghis Montenegro', 3, 'El renacimiento de el héroe'),
#  ('Bianca Wu', 5, 'La rebelión de la magia'),
#  ('Jin Zapata', 3, 'La maldición de la tierra'),
#  ('Samir Ueno', 2, 'El renacimiento de la espada'),
#  ('Yuri Ortega', 4, 'El viaje de la aventura'),
#  ('Emiko Rocha', 3, 'La batalla de la espada mágica'),
#  ('Theresa Estevez', 5, 'El viajero de la fortuna'),
#  ('Zara Gao', 2, 'El canto de sirena de el tesoro'),
#  ('Chiyoko Henriquez', 4, 'La canción de el descubrimiento'),
#  ('Ilya Watanabe', 3, 'El último viaje de la heroína'),
#  ('Kamala Gao', 5, 'La odisea de la luz'),
#  ('Bianca Alvarez', 5, 'La búsqueda de la esperanza'),
#  ('Katarina Nunes', 2, 'La sombra de el león'),
#  ('Oscar Montenegro', 5, 'El destino de la escuela'),
#  ('Orhan Olivares', 2, 'La leyenda perdida de la despedida'),
#  ('Irina Martinez', 3, 'La leyenda de la caza'),
#  ('Kamala Figueiredo', 5, 'El grito de el legado'),
#  ('Vivek Carvalho', 5, 'El resurgimiento de la revelación'),
#  ('Theresa Etxebarria', 2, 'La metamorfosis de la pesadilla'),
#  ('Sakura Lopes', 4, 'La maldición del vampiro de la pesadilla'),
#  ('Fatemeh Pereira', 2, 'El laberinto de la fuga'),
#  ('Chiyoko Gao', 4, 'El viaje de la misión'),
#  ('Darius Xu', 8, 'El ritual de la sirena'),
#  ('Fatemeh Pereira', 2, 'La búsqueda de la esperanza'),
#  ('Chiyoko Velez', 3, 'La leyenda de la caza'),
#  ('Wang Queiroz', 3, 'La maldición de el mago'),
#  ('Darius Xu', 8, 'El viaje de el lobo'),
#  ('Rosa Janssen', 3, 'Las aventuras de la desgracia'),
#  ('Fabiana Abadi', 2, 'El resurgimiento de el descubrimiento'),
#  ('Pilar Lima', 3, 'La llave de la venganza'),
#  ('Yasmin Kawaguchi', 4, 'La historia de la oscuridad'),
#  ('Tatiana Yamamoto', 4, 'El resurgimiento de el unicornio'),
#  ('Parvati Tan', 3, 'La cripta de la espada mágica'),
#  ('Bianca Alvarez', 5, 'La travesía sin retorno de la caverna'),
#  ('Darius Gao', 4, 'La redención de el susurro'),
#  ('Pilar Lima', 3, 'La escalada de la revelación'),
#  ('Rania Lopez', 4, 'La resurrección de el encuentro'),
#  ('Sakura Goncalves', 5, 'La danza de la pesadilla'),
#  ('Samir Abadi', 3, 'La llave de la venganza'),
#  ('Bianca Wu', 5, 'El canto de sirena de la bestia'),
#  ('Tatjana Watanabe', 2, 'La travesía del océano de la senda'),
#  ('Khaled Vieira', 7, 'La redención de la resistencia'),
#  ('Xin Cruz', 2, 'La cripta de la espada mágica'),
#  ('Irina Esteves', 4, 'El último viaje de la redención'),
#  ('Genghis Montenegro', 3, 'La búsqueda de el sapo'),
#  ('Rania Urbina', 4, 'La búsqueda del tesoro de el valle'),
#  ('Ursula Yilmaz', 3, 'La leyenda de el descubrimiento'),
#  ('Jin Fernandes', 2, 'El misterio de el atardecer'),
#  ('Quentin Martinez', 2, 'El grito de el camino'),
#  ('Irina Martinez', 3, 'La búsqueda del tesoro de la prisión'),
#  ('Xin Nunes', 2, 'El guardián de la leyenda'),
#  ('Gustavo Kawaguchi', 3, 'La búsqueda del tesoro de la prisión'),
#  ('Samir Abadi', 3, 'La leyenda perdida de la guerra'),
#  ('Rania Ramos', 2, 'La historia de el amor'),
#  ('Khaled Dutta', 2, 'El ritual de el explorador'),
#  ('Omar Hernandez', 7, 'La venganza de la revelación'),
#  ('Theresa Etxebarria', 2, 'La estirpe de el laberinto'),
#  ('Yusef Ivanov', 3, 'El despertar de la batalla'),
#  ('Gustavo Kawaguchi', 3, 'La llave de la estrella fugaz'),
#  ('Theresa Bianchi', 3, 'El refugio de el hechicero'),
#  ('Yuri Henriquez', 6, 'La historia de el laberinto'),
#  ('Bianca Wu', 5, 'La estirpe de la pesadilla'),
#  ('Xin Duarte', 6, 'La travesía del océano de el río'),
#  ('Omar Hernandez', 7, 'La redención de la pesadilla'),
#  ('Lakshmi Henriquez', 3, 'El prisionero de el monstruo'),
#  ('Tatiana Yamamoto', 4, 'El arco iris de el ángel'),
#  ('Irina Gao', 4, 'La fuente de la esperanza'),
#  ('Chidike Gao', 3, 'La venganza de la estrella'),
#  ('Sakura Lopes', 4, 'El hechizo de la montaña'),
#  ('Mehmet Xu', 2, 'El amanecer de la neblina'),
#  ('Wang Barros', 2, 'El vuelo mágico de el bosque'),
#  ('Giovanni Queiroz', 2, 'La cripta de la espada mágica'),
#  ('Vivek Carvalho', 5, 'La historia de el amor'),
#  ('Genghis Montenegro', 3, 'El laberinto de la fuga'),
#  ('Khaled Vieira', 7, 'La fuente de la pesadilla'),
#  ('Darius Xu', 8, 'La maldición de la muralla'),
#  ('Yuri Ortega', 4, 'La travesía de el explorador'),
#  ('Pilar Lima', 3, 'La trampa de la reina'),
#  ('Tatiana Abadi', 7, 'El secreto oscuro de la bienvenida'),
#  ('Tatjana Yamamoto', 3, 'El vuelo mágico de el bosque'),
#  ('Vivek Carvalho', 5, 'La misión de la sombra'),
#  ('Chidike Jimenez', 2, 'El camino hacia la oscuridad'),
#  ('Darius Xu', 8, 'El grito de el legado'),
#  ('Irina Esteves', 4, 'El prisionero de el sol'),
#  ('Giovanni Almeida', 3, 'El viaje de la misión'),
#  ('Sakura Pacheco', 2, 'La batalla de la espada mágica'),
#  ('Katarina Ramos', 3, 'La rebelión de la corona'),
#  ('Bianca Bianchi', 2, 'La búsqueda del tesoro de el valle'),
#  ('Xin Duarte', 6, 'El viaje de la academia'),
#  ('Darya Borges', 2, 'El refugio de la caída'),
#  ('Alessandro Lima', 2, 'La cripta de la maraña'),
#  ('Nina Zhang', 6, 'El grito de el legado'),
#  ('Elif Jimenez', 4, 'El guardián de la leyenda'),
#  ('Xin Nunes', 2, 'El ritual de la ciudad'),
#  ('Xin Cruz', 2, 'El renacimiento de el encuentro'),
#  ('Rosa Janssen', 3, 'La búsqueda del tesoro de el valle'),
#  ('Wan Ueno', 3, 'La trampa de la traición'),
#  ('Bianca Bianchi', 2, 'La resurrección de el encuentro'),
#  ('Quentin Martinez', 2, 'La travesura de el valle'),
#  ('Darius Qian', 4, 'El laberinto de la heroína'),
#  ('Yusef Ivanov', 3, 'La búsqueda de el sapo'),
#  ('Valentina Kawaguchi', 3, 'El viajero de el legado'),
#  ('Ilya Qian', 5, 'La odisea de el cielo'),
#  ('Zara Martinez', 2, 'El príncipe de la luna'),
#  ('Omar Hernandez', 7, 'El despertar de la batalla'),
#  ('Samir Diniz', 3, 'La travesía del océano de la aventura'),
#  ('Samir Tan', 3, 'El despertar de la estrella fugaz'),
#  ('Yuri Yilmaz', 3, 'Las aventuras de la fortuna'),
#  ('Irina Gao', 4, 'La rebelión de la estrella'),
#  ('Qiu Diniz', 4, 'La travesía del océano de la senda'),
#  ('Nadia Iglesias', 2, 'El tesoro de el amor'),
#  ('Mina Martinez', 2, 'El prisionero de el sol'),
#  ('Parvati Nunes', 3, 'La estirpe de la pesadilla'),
#  ('Chiyoko Velez', 3, 'El viajero de la guerra'),
#  ('Valentina Kawaguchi', 3, 'La metamorfosis de la clave'),
#  ('Theresa Alvarez', 2, 'El arco iris de el mito'),
#  ('Yuri Fernandes', 3, 'La maldición de el guardián'),
#  ('Chidike Gao', 3, 'La redención de la noche'),
#  ('Ilya Qian', 5, 'El refugio de el hechicero'),
#  ('Chiyoko Henriquez', 4, 'El espejismo de el grito'),
#  ('Patricia Montenegro', 3, 'La cripta de la aventura'),
#  ('Jin Zapata', 3, 'El regreso de la pesadilla'),
#  ('Nina Kawaguchi', 2, 'La leyenda de la estrella'),
#  ('Emiko Ferreira', 4, 'El hechizo de la tormenta'),
#  ('Yusef Etxebarria', 3, 'El príncipe de la travesía'),
#  ('Pilar Jimenez', 5, 'El viaje de la oscuridad'),
#  ('Theresa Estevez', 5, 'La maldición de la muralla'),
#  ('Han Zapata', 3, 'La fuente de el unicornio'),
#  ('Rosa Martinez', 4, 'El hechizo de la tormenta'),
#  ('Sakura Pacheco', 2, 'El enigma de el muro'),
#  ('Yusef Ortega', 3, 'La danza macabra de la pasión'),
#  ('Qiu Diniz', 4, 'La batalla de la espada mágica'),
#  ('Mikhail Wu', 5, 'La historia de el laberinto'),
#  ('Chiyoko Gao', 4, 'La redención de la pesadilla'),
#  ('Tatiana Abadi', 7, 'El príncipe de la aventura'),
#  ('Aarav Watanabe', 2, 'La travesía del océano de la senda'),
#  ('Irina Esteves', 4, 'El canto de sirena de la aldea'),
#  ('Chiyoko Velez', 3, 'El secreto de el mar'),
#  ('Chiyoko Henriquez', 4, 'El hechizo de la bruja'),
#  ('Katarina Zambrano', 3, 'La travesía de el destino'),
#  ('Mina Cruz', 3, 'La escalada de la revelación'),
#  ('Salim Qian', 2, 'Las aventuras de la luz'),
#  ('Valentina Kawaguchi', 3, 'El viajero de el amor'),
#  ('Valentina Kawaguchi', 3, 'La leyenda de la bruma'),
#  ('Zoya Ferreira', 2, 'La trampa de la reina'),
#  ('Tatiana Abadi', 7, 'La danza de la estrella'),
#  ('Katarina Zambrano', 3, 'El prisionero de el sol'),
#  ('Irina Gao', 4, 'La resurrección de la oscuridad'),
#  ('Darius Xu', 8, 'La venganza de la compañía'),
#  ('Wilhelmina Lima', 4, 'La travesía del océano de la aventura'),
#  ('Yuri Ortega', 4, 'La danza macabra de la pasión'),
#  ('Irina Abadi', 4, 'El arco iris de el ángel'),
#  ('Bianca Wu', 5, 'El secreto oscuro de el bosque'),
#  ('Rania Lopez', 4, 'El amanecer de la espada'),
#  ('Tatiana Teixeira', 3, 'El renacimiento de el héroe'),
#  ('Bianca Alvarez', 5, 'El canto de sirena de el tesoro'),
#  ('Salim Qian', 2, 'La búsqueda de la esperanza'),
#  ('Mikhail Santos', 4, 'El ritual de el descubrimiento'),
#  ('Theresa Bianchi', 3, 'El guardián de la sombra'),
#  ('Ilya Qian', 5, 'La sombra de el león'),
#  ('Yuri Fernandes', 3, 'El destino de la estrella fugaz'),
#  ('Omar Hernandez', 7, 'El último viaje de la heroína'),
#  ('Aarav Diniz', 3, 'La resurrección de la oscuridad'),
#  ('Kamala Velez', 4, 'El guardián de el valle'),
#  ('Darius Qian', 4, 'La fortuna de la noche'),
#  ('Oscar Montenegro', 5, 'El regreso de el camino'),
#  ('Genghis Henriquez', 3, 'El prisionero de la despedida'),
#  ('Theresa Estevez', 5, 'El castillo de la promesa'),
#  ('Quintus Yamamoto', 3, 'El viaje de la oscuridad'),
#  ('Xin Ramos', 2, 'La búsqueda del tesoro de la prisión'),
#  ('Elif Alvarez', 2, 'La danza macabra de el susurro'),
#  ('Genghis Montenegro', 3, 'La llave de la venganza'),
#  ('Kamala Figueiredo', 5, 'La búsqueda de la esperanza'),
#  ('Lakshmi Ortega', 2, 'El hechizo de la magia'),
#  ('Parvati Tan', 3, 'La llegada de la tormenta'),
#  ('Chidike Tan', 2, 'El prisionero de el monstruo'),
#  ('Nina Ferreira', 2, 'La leyenda perdida de la despedida'),
#  ('Pilar Jimenez', 5, 'La senda de la guerra'),
#  ('Ximena Goncalves', 2, 'La venganza de la estrella'),
#  ('Yuri Henriquez', 6, 'El regreso de la pesadilla'),
#  ('Tatjana Watanabe', 2, 'La danza macabra de la espada'),
#  ('Khaled Vieira', 7, 'El canto de sirena de la ciudad'),
#  ('Tatiana Teixeira', 3, 'El ritual de el faro'),
#  ('Yuri Henriquez', 6, 'El arco iris de el mito'),
#  ('Salim Ueno', 3, 'La rebelión de la magia'),
#  ('Bianca Alvarez', 5, 'El arco iris de el lamento'),
#  ('Samir Ueno', 2, 'El secreto oscuro de la oscuridad'),
#  ('Tatiana Abadi', 7, 'La canción de la mariposa'),
#  ('Yuri Fernandes', 4, 'La maldición de la tierra'),
#  ('Mikhail Wu', 5, 'El príncipe de la travesía'),
#  ('Lakshmi Henriquez', 3, 'La maldición de la muralla'),
#  ('Wang Queiroz', 3, 'La leyenda de la bruma'),
#  ('Alessandro Lima', 2, 'La llegada de el viaje'),
#  ('Darius Lopes', 5, 'El vuelo de la alianza'),
#  ('Chidike Jimenez', 2, 'La búsqueda del tesoro de el muro'),
#  ('Ursula Yilmaz', 3, 'La historia de el amor'),
#  ('Nadia Iglesias', 2, 'La batalla de la espada mágica'),
#  ('Ximena Joaquim', 3, 'La leyenda de la estrella'),
#  ('Sakura Lopes', 4, 'El espejismo de el destino'),
#  ('Omar Hernandez', 7, 'El pacto de la reina'),
#  ('Oscar Montenegro', 5, 'La escalada de la revelación'),
#  ('Rania Urbina', 4, 'El viaje de la alianza'),
#  ('Khaled Vieira', 7, 'La cripta de la gárgola'),
#  ('Rosa Martinez', 4, 'La historia de el camino'),
#  ('Vivek Carvalho', 5, 'El grito de el camino'),
#  ('Rania Lopez', 4, 'El grito de la libertad'),
#  ('Sakura Goncalves', 5, 'La travesía sin retorno de el encuentro'),
#  ('Nina Zhang', 6, 'El viajero de la fortuna'),
#  ('Yasmin Kawaguchi', 4, 'El viajero de la fortuna'),
#  ('Jin Janssen', 3, 'La rebelión de el abismo'),
#  ('Salim Ueno', 3, 'El destino de la escuela'),
#  ('Yusef Etxebarria', 3, 'El resurgimiento de la revelación'),
#  ('Beatriz Martinez', 2, 'El caballero de la verdad'),
#  ('Omar Hernandez', 7, 'El ritual de el descubrimiento'),
#  ('Leticia Kawaguchi', 2, 'La rebelión de el tesoro'),
#  ('Elif Jimenez', 4, 'La estirpe de el laberinto'),
#  ('Mehmet Xu', 2, 'Las aventuras de la luz'),
#  ('Wan Ueno', 3, 'La cripta de la maraña'),
#  ('Han Zapata', 3, 'La búsqueda de el sapo'),
#  ('Darius Lopes', 5, 'La fortuna de la noche'),
#  ('Wan Hernandez', 5, 'La batalla de la espada mágica'),
#  ('Darius Qian', 4, 'La historia de el amor'),
#  ('Qiu Lopes', 4, 'El viaje de la aventura'),
#  ('Mehmet Rocha', 2, 'El destino de el sueño'),
#  ('Yuri Henriquez', 6, 'La rebelión de la magia'),
#  ('Parvati Nunes', 3, 'El despertar de la corrupción'),
#  ('Theresa Estevez', 5, 'La travesura de el valle'),
#  ('Natalia Abadi', 3, 'La tormenta de el castillo'),
#  ('Kamala Figueiredo', 5, 'La trampa de el mago'),
#  ('Tatiana Abadi', 7, 'La maldición de la nube'),
#  ('Parvati Tan', 3, 'La travesía del océano de la senda'),
#  ('Sakura Quintana', 2, 'La metamorfosis de el enigma'),
#  ('Kamala Joaquim', 2, 'El castillo de la resistencia'),
#  ('Darya Borges', 2, 'El secreto de la libertad'),
#  ('Xin Ramos', 2, 'La leyenda de la estrella'),
#  ('Pilar Jimenez', 5, 'El canto de sirena de el tesoro'),
#  ('Darius Xu', 8, 'La odisea de el cielo'),
#  ('Mikhail Wu', 5, 'La trampa de el mago'),
#  ('Rania Urbina', 4, 'El último viaje de la heroína'),
#  ('Qiu Diniz', 4, 'El destino de la mariposa'),
#  ('Khaled Correia', 3, 'El guardián de la sombra'),
#  ('Mikhail Wu', 5, 'El renacimiento de el encuentro'),
#  ('Wilhelmina Lima', 4, 'La danza de el viaje'),
#  ('Samir Abadi', 3, 'El castillo de la promesa'),
#  ('Khaled Vieira', 7, 'El viajero de la guerra'),
#  ('Giovanni Almeida', 3, 'La travesía sin retorno de el sacrificio'),
#  ('Darius Gao', 4, 'La rebelión de el abismo'),
#  ('Ilya Qian', 5, 'El príncipe de la pesadilla'),
#  ('Qiu Lopes', 4, 'El laberinto de la heroína'),
#  ('Hiroko Velez', 2, 'La doncella de el amor'),
#  ('Theresa Bianchi', 3, 'La llave de la venganza'),
#  ('Nina Zhang', 6, 'El castillo de la verdad'),
#  ('Natalia Abadi', 3, 'El viaje de la misión'),
#  ('Theresa Estevez', 5, 'El misterio de el atardecer'),
#  ('Kamala Velez', 4, 'La redención de el mar'),
#  ('Katarina Xu', 2, 'El príncipe de la travesía'),
#  ('Dmitri Tan', 3, 'La travesía de el explorador'),
#  ('Samir Diniz', 3, 'El arco iris de el mito'),
#  ('Yuri Fernandes', 3, 'La historia de el laberinto'),
#  ('Mikhail Wu', 5, 'La venganza de la revelación'),
#  ('Kamala Velez', 4, 'El laberinto de el sueño'),
#  ('Chiyoko Gao', 4, 'La búsqueda del tesoro de el valle'),
#  ('Khaled Dutta', 2, 'El ritual de el faro'),
#  ('Yasmin Velez', 2, 'La sombra de la prisión'),
#  ('Yasmin Kawaguchi', 4, 'La leyenda de el descubrimiento'),
#  ('Yasmin Velez', 2, 'La llave de la ola'),
#  ('Tatiana Abadi', 7, 'La invasión de la flor'),
#  ('Kamala Gao', 5, 'El enigma de el océano'),
#  ('Kamala Gao', 5, 'El guardián de la sombra'),
#  ('Bianca Wu', 5, 'La escalada de la revelación'),
#  ('Wan Hernandez', 5, 'El hechizo de la bruja'),
#  ('Tatjana Yamamoto', 3, 'El vuelo de la princesa'),
#  ('Tatiana Abadi', 7, 'El cuento de hadas de la ley'),
#  ('Elif Jimenez', 4, 'El resurgimiento de el laberinto'),
#  ('Ilya Diniz', 3, 'La doncella de el amor'),
#  ('Sakura Quintana', 2, 'La odisea de la luz'),
#  ('Yuri Henriquez', 6, 'La redención de el mar'),
#  ('Pilar Zapata', 2, 'El renacimiento de el encuentro'),
#  ('Qiu Lopes', 4, 'El enigma de la clave'),
#  ('Sakura Lopes', 4, 'La leyenda perdida de la guerra'),
#  ('Irina Abadi', 4, 'La odisea de la pesadilla'),
#  ('Wang Queiroz', 3, 'La travesía del océano de el río'),
#  ('Tatiana Teixeira', 3, 'El viaje de la misión'),
#  ('Xin Duarte', 6, 'La redención de el susurro'),
#  ('Sakura Iglesias', 3, 'El resurgimiento de el unicornio'),
#  ('Gustavo Kawaguchi', 3, 'El tesoro escondido de el guardián'),
#  ('Genghis Henriquez', 3, 'La rebelión de el amanecer'),
#  ('Ximena Goncalves', 2, 'El resurgimiento de el laberinto'),
#  ('Samir Diniz', 3, 'La búsqueda del tesoro de la sirena'),
#  ('Aarav Watanabe', 2, 'La travesía de el destino'),
#  ('Wan Uchoa', 2, 'La historia de el camino'),
#  ('Katarina Ramos', 3, 'La metamorfosis de el océano'),
#  ('Yusef Ortega', 3, 'El enigma de el muro'),
#  ('Natalia Abadi', 3, 'El amanecer de la neblina'),
#  ('Rosa Martinez', 4, 'El arco iris de el lamento'),
#  ('Yuri Fernandes', 4, 'El enigma de el trono'),
#  ('Emiko Ferreira', 4, 'El grito de la libertad'),
#  ('Wan Uchoa', 2, 'El tesoro de el amor'),
#  ('Khaled Correia', 3, 'La misión de el monstruo'),
#  ('Katarina Xu', 2, 'El destino de el sueño'),
#  ('Nina Zhang', 6, 'La maldición de la nube'),
#  ('Han Fernandes', 2, 'El enigma de el trono'),
#  ('Samir Tan', 3, 'La odisea de la luz'),
#  ('Oscar Montenegro', 5, 'El secreto oscuro de el bosque'),
#  ('Jin Zapata', 3, 'El resurgimiento de la sirena'),
#  ('Orhan Olivares', 2, 'La danza macabra de el susurro'),
#  ('Khaled Vieira', 7, 'El destino de el sueño'),
#  ('Yuri Yilmaz', 3, 'La rebelión de la estrella'),
#  ('Chiyoko Gao', 4, 'La travesía sin retorno de el encuentro'),
#  ('Kamala Velez', 4, 'El vuelo de la princesa'),
#  ('Mina Iglesias', 4, 'El canto de sirena de el perdón'),
#  ('Yuri Henriquez', 6, 'El eclipse de el camino'),
#  ('Ursula Ramos', 2, 'La leyenda perdida de la guerra'),
#  ('Kamala Gao', 5, 'El último viaje de la heroína'),
#  ('Aarav Diniz', 3, 'El eclipse de el castillo'),
#  ('Rania Urbina', 4, 'La tormenta de la bailarina'),
#  ('Yusef Ortega', 3, 'El destino de la escuela'),
#  ('Samir Tan', 3, 'El príncipe de la pesadilla'),
#  ('Darius Lopes', 5, 'El camino hacia la despedida'),
#  ('Mina Martinez', 2, 'El eclipse de el guardián'),
#  ('Yuri Fernandes', 4, 'El guardián de la sombra')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT t_a.nombre
#
#   FROM director t_d
#
#   INNER JOIN pelicula t_p ON
#              t_d.id_director = t_p.id_director
#
#   INNER JOIN actor_participa_en_pelicula t_ap ON
#              t_p.id_pelicula = t_ap.id_pelicula
#
#   INNER JOIN actor t_a ON
#              t_ap.id_actor = t_a.id_actor
#
#   LEFT JOIN
#     (
#         SELECT
#             id_actor,
#             id_director
#         FROM
#             actor_participa_en_pelicula ap
#         INNER JOIN
#             pelicula p ON ap.id_pelicula = p.id_pelicula
#         WHERE
#             id_director != 1
#     ) out ON t_ap.id_actor = out.id_actor
#
#   WHERE
#     t_d.id_director = 1 AND
#     out.id_director IS NULL
#   GROUP BY
#     t_a.nombre
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1
# 1 rows affected.
# [('juan',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %% [raw]
# %%sql
# WITH
# --Crear una tabla con los nombres e id de los actores sin premios
# tabla1 AS(
#     SELECT nombre, actor.id_actor
#     FROM actor
#     FULL JOIN premio_mejor_actor p_ma ON
#        actor.id_actor = p_ma.id_actor
#     WHERE p_ma IS NULL
# ),
# --Juntamos la tabla anterior con actor_participa_en_pelicula
# tabla2 AS(
#     SELECT tabla1.nombre, a_pp.id_pelicula
#     FROM tabla1
#     INNER JOIN actor_participa_en_pelicula a_pp ON
#         tabla1.id_actor = a_pp.id_actor
# ),
# --Juntamos la tabla anterior con las peliculas para obtener sus nombres
# tabla3 AS(
#     SELECT tabla2.nombre, pp.nombre AS nombre_pelicula, pp.id_director
#     FROM tabla2
#     INNER JOIN pelicula pp ON
#         tabla2.id_pelicula = pp.id_pelicula
# ),
# --Juntamos la tabla anterior con los directores de dichas peliculas para obtener sus nombres
# tabla4 AS(
#     SELECT tabla3.nombre, tabla3.nombre_pelicula, tabla3.id_director, dir.nombre AS nombre_director
#     FROM tabla3
#     INNER JOIN director dir ON
#         tabla3.id_director = dir.id_director
# ),
# --Tabla auxiliar para obtener el número de peliculas de un director
# tabla5 AS(
#     SELECT DISTINCT tabla4.id_director, COUNT(DISTINCT pp.id_pelicula) AS peliculas_del_director
#     FROM tabla4
#     INNER JOIN pelicula pp ON
#         pp.id_director = tabla4.id_director
# 	GROUP BY tabla4.id_director
# ),
# --Tabla auxiliar para obtener el número de premios de un director
# tabla6 AS(
#     SELECT DISTINCT tabla4.id_director, COUNT(DISTINCT pmd.anio) AS premios_del_director
#     FROM tabla4
#     INNER JOIN premio_mejor_director pmd ON
#         pmd.id_director = tabla4.id_director
# 	GROUP BY tabla4.id_director
# ),
# --Juntamos la tabla 4 con la cantidad de premios de cada director
# tabla7 AS(
#     SELECT tabla4.nombre, tabla4.nombre_pelicula, tabla4.nombre_director, tabla4.id_director, COALESCE(tabla6.premios_del_director, 0) AS numero_de_premios_del_director
#     FROM tabla4
# 	LEFT JOIN tabla6 ON
# 		tabla4.id_director = tabla6.id_director
# ),
# --Juntamos la tabla anterior con la cantidad de peliculas de cada director
# tabla8 AS(
#     SELECT tabla7.nombre, tabla7.nombre_pelicula, tabla7.nombre_director, COALESCE(tabla5.peliculas_del_director, 0) AS numero_de_peliculas_del_director, tabla7.numero_de_premios_del_director
#     FROM tabla7
# 	LEFT JOIN tabla5 ON
# 		tabla5.id_director = tabla7.id_director
# )
# --Print
# SELECT * from tabla8
